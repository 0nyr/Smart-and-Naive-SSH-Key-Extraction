# %% [markdown]
# # Smart SSH Key Extractor

# %%
import os
import time
import numpy as np
from utils import print_, init, close, get_dataset_file_paths, load_models, read_key_files
import utils
from timeit import default_timer as timer
init() # Initialize the logging files

# %%
# program parameters
from dataclasses import dataclass

@dataclass
class ProgramParameters:
    """
    Wrapper class for program parameters.
    """

    # Sets the execution to deploy mode. Does not require key files.
    # If False: We give it '.json' files with key info to check the code.
    # If True: We give no hint about the keys, and the code should find them.
    DEPLOY = True 

    OUTPUT_DIR_PATH = os.environ['HOME'] + "/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_exctractor/out"
    DATASET_DIR_PATH = os.environ['HOME'] + '/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/'  # TODO: ???

    def __init__(self, **kwargs):
        if (
            utils.check_path_exists(self.OUTPUT_DIR_PATH) and
            utils.check_path_exists(self.DATASET_DIR_PATH)
        ):
            print("Program paths are OK.")
        else:
            print("Program paths are NOT OK.")
            exit(1)
        
        self.print_params()

    def print_params(self):
        print("Program parameters:")
        print("DEPLOY:", self.DEPLOY)
        print("OUTPUT_DIR_PATH:", self.OUTPUT_DIR_PATH)
        print("DATASET_DIR_PATH:", self.DATASET_DIR_PATH)

PARAMS = ProgramParameters()
# Out:
# Program paths are OK.
# Program parameters:
# DEPLOY: True
# OUTPUT_DIR_PATH: /home/onyr/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_exctractor/out
# DATASET_DIR_PATH: /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/

# %% [markdown]
# ## Functions

# %%
def get_run_length_encoded(data_block: np.ndarray):
    """
    Takes a data block of bytes.
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block.

    Example:
        data_block = [a,a,a,a,b,b,c,a,a]
        byte_array = [a,b,c,a]
        counts = [4,2,1,2]
    """

    idx = 1
    byte_array = []
    counts = []
    count = 1
    curr_char = data_block[0]
    while idx < len(data_block):
        if data_block[idx] == curr_char:
            idx += 1
            count += 1
            continue

        else:
            byte_array.append(curr_char)
            counts.append(count)

            count = 1
            curr_char = data_block[idx]

        idx += 1

    # Append the last byte and count
    byte_array.append(curr_char)
    counts.append(count)

    return bytearray(byte_array), counts

# %%
def generate_rle_representation(raw_data: bytearray):
    """
    Takes a data block of bytes (NOTE: byte == octet != bit).
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block, and the cumulative sum of the counts.
    """

    reshaped = np.reshape(raw_data, newshape=(int(len(raw_data) / 8), 8))

    # Here we take reshaped array and compute the numerical row and column wise gradient and count the number
    # of zeroes in each row. If there are more than 4 zeros which means there is a pattern repeating and
    # is not a key. This is a very conservative estimate for better recall
    num_row = int(len(raw_data) / 8)

    # x_grad = np.abs(np.diff(reshaped.astype(int), axis=1, append=np.zeros((num_row, 1)))).astype(bool)
    # y_grad = np.abs(np.diff(reshaped.astype(int), axis=0, append=np.zeros((1, 8)))).astype(bool)
    # The above numerical gradient computation is transformed into a single step below

    poss_key_locs = (np.count_nonzero(np.abs(np.diff(reshaped.astype(int), axis=1,
                                                     append=np.zeros((num_row, 1)))).astype(bool) &
                                      np.abs(np.diff(reshaped.astype(int), axis=0,
                                                     append=np.zeros((1, 8)))).astype(bool),
                                      axis=1) >= 4).astype(int)  # Changed from 4 to 3 to accommodate for 12 byte keys

    # This part addresses the issue of 12 byte keys. There could be two identical byte_array next to each other in the
    # last 4 bytes which would make it impossible for a key loc. We modify that if there is a possibility for a key
    idx = 1
    while idx < len(poss_key_locs):
        # Last 4 byte_array must be zeros and first four should have at least 3 unique byte_array
        if poss_key_locs[idx] == 0 and poss_key_locs[idx-1] == 1 and \
                all(reshaped[idx][4:]) == 0 and len(set(reshaped[idx][:4])) > 2:
            poss_key_locs[idx] = 1
        idx += 1

    # Roll the data to the left
    rolled = np.roll(poss_key_locs, -1)
    # The key cannot start at the last byte and then the block contain the whole key.
    # So the last value is set to False
    rolled[-1] = False
    poss_key_locs = (poss_key_locs & rolled).astype(int)

    # Roll right and OR it. The whole operation is similar to the opening morphological operation
    rolled = np.roll(poss_key_locs, 1)
    rolled[0] = False

    poss_key_locs = poss_key_locs | rolled

    byte_array, counts = get_run_length_encoded(poss_key_locs)

    cum_sum = [0]

    for idx in range(len(counts)):
        cum_sum.append(cum_sum[idx] + counts[idx])

    cum_sum = [x * 8 for x in cum_sum] # TODO: ???

    # The last offset is not required for the cumulative sum
    return byte_array, counts, cum_sum[:-1]

# %%
def get_slices(data, offsets, keys, max_key_size=128, deploy=False):
    """
    Takes a data block and a list of offsets.
    Cut the data block at the offsets and return a list of data blocks.
    Also return for each data block
    a label indicating if it contains a key or not. If deploy is True,
    the label is always 0.

    If we test the code (deploy=False), we additionnaly tests 
    if the data block contains a key.
    """

    data_blocks = []
    labels = []
    last_frame_added = False
    key_count = [0] * len(keys)
    for offset in offsets:
        if offset + max_key_size > len(data):
            curr_data = data[-max_key_size:]
            last_frame_added = True
        else:
            curr_data = data[offset:offset+max_key_size]
        data_blocks.append(curr_data)
        
        if deploy is True:
            labels.append(0)
            continue
            
        found = [l_idx for l_idx in range(len(keys)) if keys[l_idx] in curr_data]

        if len(found) > 0:
            labels.append(1)
            for key_idx in set(found):
                key_count[key_idx] += 1

        else:
            labels.append(0)

        if last_frame_added is True:
            break
    
    if deploy is False:
        assert len(data_blocks) == len(labels)
        assert sum(labels) > 0 and sum(labels) >= len(keys)
        assert min(key_count) != 0
    
    return data_blocks, labels

# %%
def build_encoded_dataset(heap_paths, key_paths, max_key_size=128, deploy=False):
    """
    Takes a list of heap paths and a list of key paths.
    For each heap path, it reads the heap file and the corresponding key file.
    It then generates a list of data blocks and a list of labels.
    The data blocks are generated by cutting the heap file at the offsets
    where a key is likely to be found. The labels indicate if the data block
    is sure to contains a key or not (when anotation is provided (deploy == False)).

    Returns a list of data blocks and a list of labels.
    """

    dataset = []
    labels = []
    for heap_path, key_path in zip(heap_paths, key_paths):

        # Check if the key path corresponds to the heap path, then read the required data
        curr_keys = ['EMPTY KEYS']
        if deploy is False:
            assert (key_path.replace(".json", "-heap.raw") == heap_path)
            curr_keys = read_key_files(key_path)
            # Remove repeated keys. This is an issue for some older versions of OpenSSH
            curr_keys = list(map(bytearray, set(tuple(x) for x in curr_keys)))

        with open(heap_path, "rb") as fp:
            data = bytearray(fp.read())
            
        byte_array, counts, cum_sum = generate_rle_representation(data)
        
        # a key can only starts with a byte of value 1, example: 00000001 10100111 101011001 ...
        viable_offsets = [cum_sum[idx] for idx in range(len(cum_sum)) if byte_array[idx] == 1]
        slices, curr_labels = get_slices(
            data=data, 
            offsets=viable_offsets, 
            max_key_size=max_key_size, 
            keys=curr_keys, 
            deploy=deploy
        )
        dataset.extend(slices)
        labels.extend(curr_labels)

    assert len(labels) == len(dataset)

    return dataset, labels

# %%
def generate_probable_slices(clf, heap_paths, key_paths, params: ProgramParameters):
    # Sort the heap paths and key paths, so it easier to group them by version and key length
    heap_paths.sort()
    key_paths.sort()
    
    # For each of the keys
    for idx in range(len(heap_paths)):
        start = time.time()

        key_path: str = ""
        if params.DEPLOY is False:
            key_path = key_paths[idx]
            
        dataset, curr_labels = build_encoded_dataset(
            heap_paths=[heap_paths[idx]],
            key_paths=[key_path], 
            deploy=params.DEPLOY
        )

        x_test = np.array(dataset).astype(int)
        curr_pred = clf.predict(x_test) # Make predictions

        # path manipulation to tranform input file paths to output file paths
        # example: transform "$INPUT/lastdir/heap.raw" to "$OUTPUT/lastdir/heap.txt
        file_name = os.path.basename(heap_paths[idx])
        file_name = file_name.replace(".raw", ".txt")
        sub_dir = os.path.dirname(heap_paths[idx]).split("/")[-1]
        dir_path = os.path.join(params.OUTPUT_DIR_PATH, sub_dir)
        output_path = os.path.join(dir_path, file_name)

        if os.path.exists(dir_path) is False:
            os.makedirs(dir_path)

        with open(output_path, 'w') as file:
            for inner_idx, pred in enumerate(curr_pred):
                # save if prediction not 0
                if pred != 0:
                    # format block to two digit hex
                    temp = ''.join(format(x, '02x') for x in dataset[inner_idx])
                    file.write(temp + "\n")

        end = time.time()
        print_('Total time taken for file %s: %f' % (heap_paths[idx], (end - start)))

# %% [markdown]
# ## Execution

# %%
# Load the models
clf = load_models(load_high_recall_only=True)
# Out:
# 2022-12-08 11:26:08.630593:	Time taken for loading high recall classifier: 0.409897

# %%
# Search for all the files with in the test directory
# start = time.time()
start = timer()
heap_paths, key_paths = get_dataset_file_paths(PARAMS.DATASET_DIR_PATH, deploy=PARAMS.DEPLOY)
end = timer()
# end = time.time()
print_('Time taken for finding all files: %f' % (end - start))

# print first 5 values in heap_paths
print("heap_paths:", heap_paths[:5])
print("key_paths:", key_paths[:5])
# Out:
# 2022-12-08 11:26:08.727096:	Time taken for finding all files: 0.003326
# heap_paths: ['/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw']
# key_paths: []

# %%
generate_probable_slices(clf=clf, heap_paths=heap_paths, key_paths=key_paths, params=PARAMS)
# Out:
# 2022-12-08 11:26:08.809755:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10237-1650982250-heap.raw: 0.018049
# 2022-12-08 11:26:08.824183:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10240-1650982250-heap.raw: 0.014354
# 2022-12-08 11:26:08.838903:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10243-1650982250-heap.raw: 0.014675
# 2022-12-08 11:26:08.853373:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10246-1650982250-heap.raw: 0.014386
# 2022-12-08 11:26:08.867665:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10249-1650982250-heap.raw: 0.014251
# 2022-12-08 11:26:08.881302:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10252-1650982250-heap.raw: 0.013590
# 2022-12-08 11:26:08.895299:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10255-1650982250-heap.raw: 0.013953
# 2022-12-08 11:26:08.908703:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10258-1650982250-heap.raw: 0.013371
# 2022-12-08 11:26:08.922543:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10261-1650982250-heap.raw: 0.013807
# 2022-12-08 11:26:08.936462:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10264-1650982250-heap.raw: 0.013880
# 2022-12-08 11:26:08.950814:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10267-1650982250-heap.raw: 0.014278
# 2022-12-08 11:26:08.964988:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10270-1650982250-heap.raw: 0.014134
# 2022-12-08 11:26:08.982930:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10273-1650982250-heap.raw: 0.017897
# 2022-12-08 11:26:08.998939:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10276-1650982250-heap.raw: 0.015961
# 2022-12-08 11:26:09.016243:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10279-1650982250-heap.raw: 0.017256
# 2022-12-08 11:26:09.031031:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10282-1650982250-heap.raw: 0.014693
# 2022-12-08 11:26:09.046560:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10285-1650982250-heap.raw: 0.015486
# 2022-12-08 11:26:09.061571:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10288-1650982250-heap.raw: 0.014924
# 2022-12-08 11:26:09.075829:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10291-1650982250-heap.raw: 0.014214
# 2022-12-08 11:26:09.090771:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10294-1650982250-heap.raw: 0.014896
# 2022-12-08 11:26:09.109881:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10297-1650982250-heap.raw: 0.019059
# 2022-12-08 11:26:09.123995:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10300-1650982250-heap.raw: 0.014063
# 2022-12-08 11:26:09.137684:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10303-1650982250-heap.raw: 0.013640
# 2022-12-08 11:26:09.152867:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10306-1650982250-heap.raw: 0.014868
# 2022-12-08 11:26:09.167034:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10309-1650982250-heap.raw: 0.014127
# 2022-12-08 11:26:09.181910:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10312-1650982250-heap.raw: 0.014838
# 2022-12-08 11:26:09.196443:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10315-1650982250-heap.raw: 0.014499
# 2022-12-08 11:26:09.212072:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10318-1650982250-heap.raw: 0.015590
# 2022-12-08 11:26:09.229265:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10321-1650982250-heap.raw: 0.017151
# 2022-12-08 11:26:09.247802:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10324-1650982250-heap.raw: 0.018460
# 2022-12-08 11:26:09.263197:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10327-1650982250-heap.raw: 0.015350
# 2022-12-08 11:26:09.278460:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10330-1650982250-heap.raw: 0.015179
# 2022-12-08 11:26:09.293082:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10333-1650982250-heap.raw: 0.014585
# 2022-12-08 11:26:09.307526:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10336-1650982250-heap.raw: 0.014402
# 2022-12-08 11:26:09.321503:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10339-1650982250-heap.raw: 0.013938
# 2022-12-08 11:26:09.335776:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10342-1650982250-heap.raw: 0.014229
# 2022-12-08 11:26:09.350676:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10345-1650982250-heap.raw: 0.014854
# 2022-12-08 11:26:09.364420:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10348-1650982250-heap.raw: 0.013654
# 2022-12-08 11:26:09.378214:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10351-1650982250-heap.raw: 0.013755
# 2022-12-08 11:26:09.392010:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10354-1650982250-heap.raw: 0.013755
# 2022-12-08 11:26:09.406033:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10357-1650982250-heap.raw: 0.013981
# 2022-12-08 11:26:09.420014:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10360-1650982250-heap.raw: 0.013940
# 2022-12-08 11:26:09.435803:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10363-1650982250-heap.raw: 0.015732
# 2022-12-08 11:26:09.451881:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10366-1650982250-heap.raw: 0.015924
# 2022-12-08 11:26:09.467899:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10370-1650982250-heap.raw: 0.015971
# 2022-12-08 11:26:09.483499:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10373-1650982250-heap.raw: 0.015520
# 2022-12-08 11:26:09.502495:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10376-1650982250-heap.raw: 0.018946
# 2022-12-08 11:26:09.520242:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10379-1650982250-heap.raw: 0.017702
# 2022-12-08 11:26:09.538077:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10382-1650982250-heap.raw: 0.017776
# 2022-12-08 11:26:09.553465:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10385-1650982250-heap.raw: 0.015351
# 2022-12-08 11:26:09.569425:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10388-1650982250-heap.raw: 0.015775
# 2022-12-08 11:26:09.588023:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10391-1650982250-heap.raw: 0.018541
# 2022-12-08 11:26:09.603692:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10394-1650982250-heap.raw: 0.015613
# 2022-12-08 11:26:09.623679:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10397-1650982250-heap.raw: 0.019926
# 2022-12-08 11:26:09.640165:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10400-1650982250-heap.raw: 0.016438
# 2022-12-08 11:26:09.655557:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10403-1650982250-heap.raw: 0.015302
# 2022-12-08 11:26:09.672753:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10406-1650982250-heap.raw: 0.017145
# 2022-12-08 11:26:09.690187:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10409-1650982250-heap.raw: 0.017329
# 2022-12-08 11:26:09.705031:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10412-1650982250-heap.raw: 0.014797
# 2022-12-08 11:26:09.720356:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10415-1650982250-heap.raw: 0.015270
# 2022-12-08 11:26:09.735988:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10418-1650982250-heap.raw: 0.015576
# 2022-12-08 11:26:09.752245:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10421-1650982250-heap.raw: 0.016184
# 2022-12-08 11:26:09.771630:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10424-1650982250-heap.raw: 0.019319
# 2022-12-08 11:26:09.787430:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10427-1650982250-heap.raw: 0.015552
# 2022-12-08 11:26:09.802877:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10430-1650982250-heap.raw: 0.015258
# 2022-12-08 11:26:09.824492:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10433-1650982250-heap.raw: 0.021550
# 2022-12-08 11:26:09.840994:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10436-1650982250-heap.raw: 0.016454
# 2022-12-08 11:26:09.856463:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10439-1650982250-heap.raw: 0.015419
# 2022-12-08 11:26:09.871409:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10442-1650982250-heap.raw: 0.014831
# 2022-12-08 11:26:09.886504:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10445-1650982250-heap.raw: 0.015032
# 2022-12-08 11:26:09.901070:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10448-1650982250-heap.raw: 0.014457
# 2022-12-08 11:26:09.916130:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10451-1650982250-heap.raw: 0.015008
# 2022-12-08 11:26:09.931360:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10454-1650982250-heap.raw: 0.015182
# 2022-12-08 11:26:09.952454:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10457-1650982250-heap.raw: 0.021034
# 2022-12-08 11:26:09.967506:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10460-1650982250-heap.raw: 0.014974
# 2022-12-08 11:26:09.983134:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10463-1650982250-heap.raw: 0.015563
# 2022-12-08 11:26:09.999336:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10466-1650982250-heap.raw: 0.016106
# 2022-12-08 11:26:10.014704:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10469-1650982250-heap.raw: 0.015321
# 2022-12-08 11:26:10.028652:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10472-1650982250-heap.raw: 0.013891
# 2022-12-08 11:26:10.043407:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10475-1650982250-heap.raw: 0.014709
# 2022-12-08 11:26:10.057935:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10478-1650982250-heap.raw: 0.014490
# 2022-12-08 11:26:10.073042:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10481-1650982250-heap.raw: 0.015037
# 2022-12-08 11:26:10.087573:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10484-1650982250-heap.raw: 0.014490
# 2022-12-08 11:26:10.102213:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10487-1650982250-heap.raw: 0.014582
# 2022-12-08 11:26:10.116379:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10490-1650982250-heap.raw: 0.014124
# 2022-12-08 11:26:10.130754:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10493-1650982250-heap.raw: 0.014332
# 2022-12-08 11:26:10.145438:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10496-1650982250-heap.raw: 0.014623
# 2022-12-08 11:26:10.160227:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10499-1650982250-heap.raw: 0.014708
# 2022-12-08 11:26:10.174728:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10502-1650982250-heap.raw: 0.014440
# 2022-12-08 11:26:10.189300:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10505-1650982250-heap.raw: 0.014528
# 2022-12-08 11:26:10.204316:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10508-1650982250-heap.raw: 0.014932
# 2022-12-08 11:26:10.218817:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10511-1650982250-heap.raw: 0.014451
# 2022-12-08 11:26:10.233829:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10514-1650982250-heap.raw: 0.014963
# 2022-12-08 11:26:10.248589:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10517-1650982250-heap.raw: 0.014712
# 2022-12-08 11:26:10.265376:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10520-1650982250-heap.raw: 0.016743
# 2022-12-08 11:26:10.282530:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10523-1650982250-heap.raw: 0.017056
# 2022-12-08 11:26:10.297726:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10526-1650982250-heap.raw: 0.015150
# 2022-12-08 11:26:10.312257:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10529-1650982250-heap.raw: 0.014432
# 2022-12-08 11:26:10.326552:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10532-1650982250-heap.raw: 0.014257
# 2022-12-08 11:26:10.341122:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10535-1650982250-heap.raw: 0.014518
# 2022-12-08 11:26:10.359347:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10538-1650982549-heap.raw: 0.018163
# 2022-12-08 11:26:10.375165:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10541-1650982549-heap.raw: 0.015766
# 2022-12-08 11:26:10.392874:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10544-1650982549-heap.raw: 0.017658
# 2022-12-08 11:26:10.407355:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10547-1650982549-heap.raw: 0.014407
# 2022-12-08 11:26:10.421335:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10550-1650982549-heap.raw: 0.013925
# 2022-12-08 11:26:10.435392:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10553-1650982549-heap.raw: 0.014008
# 2022-12-08 11:26:10.449260:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10556-1650982549-heap.raw: 0.013819
# 2022-12-08 11:26:10.463687:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10559-1650982549-heap.raw: 0.014380
# 2022-12-08 11:26:10.477950:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10562-1650982549-heap.raw: 0.014229
# 2022-12-08 11:26:10.492688:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10565-1650982549-heap.raw: 0.014657
# 2022-12-08 11:26:10.507822:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10568-1650982549-heap.raw: 0.015087
# 2022-12-08 11:26:10.523334:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10571-1650982549-heap.raw: 0.015416
# 2022-12-08 11:26:10.538171:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10574-1650982549-heap.raw: 0.014790
# 2022-12-08 11:26:10.553213:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10577-1650982549-heap.raw: 0.014997
# 2022-12-08 11:26:10.567649:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10580-1650982549-heap.raw: 0.014395
# 2022-12-08 11:26:10.580847:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw: 0.013168
# 2022-12-08 11:26:10.595275:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10586-1650982549-heap.raw: 0.014392
# 2022-12-08 11:26:10.609000:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10589-1650982549-heap.raw: 0.013647
# 2022-12-08 11:26:10.623760:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10592-1650982549-heap.raw: 0.014722
# 2022-12-08 11:26:10.636534:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10595-1650982549-heap.raw: 0.012738
# 2022-12-08 11:26:10.651746:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10598-1650982549-heap.raw: 0.015169
# 2022-12-08 11:26:10.665882:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10601-1650982549-heap.raw: 0.014094
# 2022-12-08 11:26:10.680463:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10607-1650982549-heap.raw: 0.014545
# 2022-12-08 11:26:10.694098:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10610-1650982549-heap.raw: 0.013564
# 2022-12-08 11:26:10.707760:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10613-1650982549-heap.raw: 0.013624
# 2022-12-08 11:26:10.723265:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10616-1650982549-heap.raw: 0.015456
# 2022-12-08 11:26:10.737155:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10619-1650982549-heap.raw: 0.013791
# 2022-12-08 11:26:10.750235:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10622-1650982549-heap.raw: 0.013050
# 2022-12-08 11:26:10.763920:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10625-1650982549-heap.raw: 0.013649
# 2022-12-08 11:26:10.777227:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10628-1650982549-heap.raw: 0.013274
# 2022-12-08 11:26:10.790256:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10631-1650982549-heap.raw: 0.012994
# 2022-12-08 11:26:10.803978:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10634-1650982549-heap.raw: 0.013659
# 2022-12-08 11:26:10.817586:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10637-1650982549-heap.raw: 0.013530
# 2022-12-08 11:26:10.830915:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10640-1650982549-heap.raw: 0.013302
# 2022-12-08 11:26:10.845976:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10643-1650982549-heap.raw: 0.015021
# 2022-12-08 11:26:10.861039:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10646-1650982549-heap.raw: 0.015013
# 2022-12-08 11:26:10.877327:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10649-1650982549-heap.raw: 0.016236
# 2022-12-08 11:26:10.891392:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10652-1650982549-heap.raw: 0.014031
# 2022-12-08 11:26:10.905102:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10655-1650982549-heap.raw: 0.013642
# 2022-12-08 11:26:10.919219:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10658-1650982549-heap.raw: 0.014081
# 2022-12-08 11:26:10.932913:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10661-1650982549-heap.raw: 0.013660
# 2022-12-08 11:26:10.947357:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10664-1650982549-heap.raw: 0.014374
# 2022-12-08 11:26:10.960602:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10667-1650982549-heap.raw: 0.013213
# 2022-12-08 11:26:10.974426:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10670-1650982549-heap.raw: 0.013789
# 2022-12-08 11:26:10.988363:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10673-1650982549-heap.raw: 0.013895
# 2022-12-08 11:26:11.001209:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10676-1650982549-heap.raw: 0.012814
# 2022-12-08 11:26:11.015620:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10679-1650982549-heap.raw: 0.014375
# 2022-12-08 11:26:11.029822:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10682-1650982549-heap.raw: 0.014127
# 2022-12-08 11:26:11.044457:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10685-1650982549-heap.raw: 0.014601
# 2022-12-08 11:26:11.058830:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10688-1650982549-heap.raw: 0.014334
# 2022-12-08 11:26:11.072484:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10691-1650982549-heap.raw: 0.013620
# 2022-12-08 11:26:11.087190:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10694-1650982549-heap.raw: 0.014666
# 2022-12-08 11:26:11.103145:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10697-1650982549-heap.raw: 0.015911
# 2022-12-08 11:26:11.118497:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10700-1650982549-heap.raw: 0.015273
# 2022-12-08 11:26:11.132269:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10703-1650982549-heap.raw: 0.013732
# 2022-12-08 11:26:11.147176:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10706-1650982549-heap.raw: 0.014868
# 2022-12-08 11:26:11.161026:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10709-1650982549-heap.raw: 0.013757
# 2022-12-08 11:26:11.174156:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10712-1650982549-heap.raw: 0.013087
# 2022-12-08 11:26:11.188154:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10715-1650982549-heap.raw: 0.013954
# 2022-12-08 11:26:11.200555:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10718-1650982549-heap.raw: 0.012369
# 2022-12-08 11:26:11.214273:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw: 0.013684
# 2022-12-08 11:26:11.228229:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10724-1650982549-heap.raw: 0.013919
# 2022-12-08 11:26:11.242400:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10727-1650982549-heap.raw: 0.014102
# 2022-12-08 11:26:11.255527:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw: 0.013089
# 2022-12-08 11:26:11.269496:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10733-1650982549-heap.raw: 0.013932
# 2022-12-08 11:26:11.282701:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10736-1650982549-heap.raw: 0.013170
# 2022-12-08 11:26:11.296288:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10739-1650982549-heap.raw: 0.013547
# 2022-12-08 11:26:11.313167:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10742-1650982549-heap.raw: 0.016842
# 2022-12-08 11:26:11.327436:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10745-1650982549-heap.raw: 0.014189
# 2022-12-08 11:26:11.342403:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10748-1650982549-heap.raw: 0.014922
# 2022-12-08 11:26:11.356682:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10751-1650982549-heap.raw: 0.014237
# 2022-12-08 11:26:11.371005:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw: 0.014249
# 2022-12-08 11:26:11.385686:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10757-1650982549-heap.raw: 0.014642
# 2022-12-08 11:26:11.405066:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10760-1650982549-heap.raw: 0.019345
# 2022-12-08 11:26:11.418285:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10763-1650982549-heap.raw: 0.013185
# 2022-12-08 11:26:11.437177:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10766-1650982549-heap.raw: 0.018818
# 2022-12-08 11:26:11.451130:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10769-1650982549-heap.raw: 0.013866
# 2022-12-08 11:26:11.471073:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10772-1650982549-heap.raw: 0.019901
# 2022-12-08 11:26:11.485115:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10775-1650982549-heap.raw: 0.014004
# 2022-12-08 11:26:11.505640:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10778-1650982549-heap.raw: 0.020485
# 2022-12-08 11:26:11.521154:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10781-1650982549-heap.raw: 0.015471
# 2022-12-08 11:26:11.540440:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10784-1650982549-heap.raw: 0.019204
# 2022-12-08 11:26:11.554389:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10787-1650982549-heap.raw: 0.013912
# 2022-12-08 11:26:11.568631:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10790-1650982549-heap.raw: 0.014199
# 2022-12-08 11:26:11.582350:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10793-1650982549-heap.raw: 0.013662
# 2022-12-08 11:26:11.595902:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw: 0.013514
# 2022-12-08 11:26:11.609193:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10799-1650982549-heap.raw: 0.013259
# 2022-12-08 11:26:11.622118:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10802-1650982549-heap.raw: 0.012898
# 2022-12-08 11:26:11.636038:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10805-1650982549-heap.raw: 0.013888
# 2022-12-08 11:26:11.650604:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10808-1650982549-heap.raw: 0.014531
# 2022-12-08 11:26:11.665101:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10811-1650982549-heap.raw: 0.014449
# 2022-12-08 11:26:11.679587:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10814-1650982549-heap.raw: 0.014445
# 2022-12-08 11:26:11.698615:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10817-1650982549-heap.raw: 0.018987
# 2022-12-08 11:26:11.713064:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10820-1650982549-heap.raw: 0.014410
# 2022-12-08 11:26:11.731724:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10823-1650982549-heap.raw: 0.018622
# 2022-12-08 11:26:11.746521:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10826-1650982549-heap.raw: 0.014734
# 2022-12-08 11:26:11.761474:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10829-1650982549-heap.raw: 0.014899
# 2022-12-08 11:26:11.775748:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10832-1650982549-heap.raw: 0.014232
# 2022-12-08 11:26:11.789852:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10835-1650982549-heap.raw: 0.014019
# 2022-12-08 11:26:11.803627:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10838-1650982549-heap.raw: 0.013742
# 2022-12-08 11:26:11.817597:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10002-1650981891-heap.raw: 0.013934
# 2022-12-08 11:26:11.830906:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10005-1650981891-heap.raw: 0.013269
# 2022-12-08 11:26:11.844142:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10008-1650981891-heap.raw: 0.013200
# 2022-12-08 11:26:11.857524:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10011-1650981891-heap.raw: 0.013348
# 2022-12-08 11:26:11.870656:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10014-1650981891-heap.raw: 0.013062
# 2022-12-08 11:26:11.886563:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10017-1650981891-heap.raw: 0.015874
# 2022-12-08 11:26:11.900291:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10020-1650981891-heap.raw: 0.013693
# 2022-12-08 11:26:11.914169:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10023-1650981891-heap.raw: 0.013848
# 2022-12-08 11:26:11.928740:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10026-1650981891-heap.raw: 0.014539
# 2022-12-08 11:26:11.942563:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10029-1650981891-heap.raw: 0.013796
# 2022-12-08 11:26:11.957072:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10032-1650981891-heap.raw: 0.014450
# 2022-12-08 11:26:11.971997:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10035-1650981891-heap.raw: 0.014883
# 2022-12-08 11:26:11.989295:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10038-1650981891-heap.raw: 0.017250
# 2022-12-08 11:26:12.003160:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10041-1650981891-heap.raw: 0.013789
# 2022-12-08 11:26:12.017949:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10044-1650981891-heap.raw: 0.014757
# 2022-12-08 11:26:12.032189:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10047-1650981891-heap.raw: 0.014208
# 2022-12-08 11:26:12.045283:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10050-1650981891-heap.raw: 0.013067
# 2022-12-08 11:26:12.057937:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10053-1650981891-heap.raw: 0.012630
# 2022-12-08 11:26:12.071122:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10056-1650981891-heap.raw: 0.013160
# 2022-12-08 11:26:12.085297:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10059-1650981891-heap.raw: 0.014082
# 2022-12-08 11:26:12.099159:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10062-1650981891-heap.raw: 0.013829
# 2022-12-08 11:26:12.112421:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10065-1650981891-heap.raw: 0.013234
# 2022-12-08 11:26:12.126535:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10068-1650981891-heap.raw: 0.014078
# 2022-12-08 11:26:12.140054:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10071-1650981891-heap.raw: 0.013485
# 2022-12-08 11:26:12.153776:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10074-1650981891-heap.raw: 0.013698
# 2022-12-08 11:26:12.167307:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10077-1650981891-heap.raw: 0.013489
# 2022-12-08 11:26:12.181480:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10080-1650981891-heap.raw: 0.014139
# 2022-12-08 11:26:12.195280:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10083-1650981891-heap.raw: 0.013767
# 2022-12-08 11:26:12.209831:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10086-1650981891-heap.raw: 0.014503
# 2022-12-08 11:26:12.224230:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10089-1650981891-heap.raw: 0.014352
# 2022-12-08 11:26:12.239612:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10092-1650981891-heap.raw: 0.015341
# 2022-12-08 11:26:12.252901:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10095-1650981891-heap.raw: 0.013249
# 2022-12-08 11:26:12.266267:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10098-1650981891-heap.raw: 0.013335
# 2022-12-08 11:26:12.280184:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10101-1650981891-heap.raw: 0.013892
# 2022-12-08 11:26:12.293993:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10104-1650981891-heap.raw: 0.013759
# 2022-12-08 11:26:12.307608:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10107-1650981891-heap.raw: 0.013574
# 2022-12-08 11:26:12.321977:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10110-1650981891-heap.raw: 0.014328
# 2022-12-08 11:26:12.335511:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10113-1650981891-heap.raw: 0.013498
# 2022-12-08 11:26:12.348657:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10116-1650981891-heap.raw: 0.013116
# 2022-12-08 11:26:12.361872:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10119-1650981891-heap.raw: 0.013184
# 2022-12-08 11:26:12.376193:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10122-1650981891-heap.raw: 0.014260
# 2022-12-08 11:26:12.390046:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10125-1650981891-heap.raw: 0.013811
# 2022-12-08 11:26:12.404455:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10128-1650981891-heap.raw: 0.014374
# 2022-12-08 11:26:12.419289:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10131-1650981891-heap.raw: 0.014779
# 2022-12-08 11:26:12.433111:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10134-1650981891-heap.raw: 0.013788
# 2022-12-08 11:26:12.447433:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10137-1650981891-heap.raw: 0.014283
# 2022-12-08 11:26:12.461433:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10140-1650981891-heap.raw: 0.013966
# 2022-12-08 11:26:12.475030:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10143-1650981891-heap.raw: 0.013562
# 2022-12-08 11:26:12.489622:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10146-1650981891-heap.raw: 0.014549
# 2022-12-08 11:26:12.503893:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10149-1650981891-heap.raw: 0.014196
# 2022-12-08 11:26:12.518587:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10152-1650981891-heap.raw: 0.014654
# 2022-12-08 11:26:12.531972:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10155-1650981891-heap.raw: 0.013352
# 2022-12-08 11:26:12.545294:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10158-1650981891-heap.raw: 0.013294
# 2022-12-08 11:26:12.558018:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10161-1650981891-heap.raw: 0.012698
# 2022-12-08 11:26:12.571427:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10164-1650981891-heap.raw: 0.013383
# 2022-12-08 11:26:12.585385:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10167-1650981891-heap.raw: 0.013906
# 2022-12-08 11:26:12.598365:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10170-1650981891-heap.raw: 0.012949
# 2022-12-08 11:26:12.612426:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10173-1650981891-heap.raw: 0.014035
# 2022-12-08 11:26:12.626261:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10176-1650981891-heap.raw: 0.013786
# 2022-12-08 11:26:12.639678:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10179-1650981891-heap.raw: 0.013385
# 2022-12-08 11:26:12.652884:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10182-1650981891-heap.raw: 0.013175
# 2022-12-08 11:26:12.665908:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10185-1650981891-heap.raw: 0.012993
# 2022-12-08 11:26:12.679094:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10188-1650981891-heap.raw: 0.013157
# 2022-12-08 11:26:12.692406:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10191-1650981891-heap.raw: 0.013272
# 2022-12-08 11:26:12.706218:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10194-1650981891-heap.raw: 0.013768
# 2022-12-08 11:26:12.719354:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10197-1650981891-heap.raw: 0.013106
# 2022-12-08 11:26:12.732901:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10200-1650981891-heap.raw: 0.013513
# 2022-12-08 11:26:12.746306:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10203-1650981891-heap.raw: 0.013371
# 2022-12-08 11:26:12.759027:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10206-1650981891-heap.raw: 0.012697
# 2022-12-08 11:26:12.772041:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10209-1650981891-heap.raw: 0.012987
# 2022-12-08 11:26:12.785535:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10212-1650981891-heap.raw: 0.013464
# 2022-12-08 11:26:12.799158:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10215-1650981891-heap.raw: 0.013562
# 2022-12-08 11:26:12.812312:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10218-1650981891-heap.raw: 0.013123
# 2022-12-08 11:26:12.825956:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10221-1650981891-heap.raw: 0.013614
# 2022-12-08 11:26:12.840594:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10224-1650981891-heap.raw: 0.014564
# 2022-12-08 11:26:12.854140:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10227-1650981891-heap.raw: 0.013507
# 2022-12-08 11:26:12.868042:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10230-1650981891-heap.raw: 0.013861
# 2022-12-08 11:26:12.883030:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10233-1650981891-heap.raw: 0.014939
# 2022-12-08 11:26:12.897170:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9936-1650981891-heap.raw: 0.014090
# 2022-12-08 11:26:12.912629:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9939-1650981891-heap.raw: 0.015364
# 2022-12-08 11:26:12.927061:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9942-1650981891-heap.raw: 0.014386
# 2022-12-08 11:26:12.941541:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9945-1650981891-heap.raw: 0.014438
# 2022-12-08 11:26:12.955737:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9948-1650981891-heap.raw: 0.014150
# 2022-12-08 11:26:12.970010:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9951-1650981891-heap.raw: 0.014229
# 2022-12-08 11:26:12.984905:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9954-1650981891-heap.raw: 0.014848
# 2022-12-08 11:26:12.999615:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9957-1650981891-heap.raw: 0.014666
# 2022-12-08 11:26:13.015182:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9960-1650981891-heap.raw: 0.015465
# 2022-12-08 11:26:13.029434:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9963-1650981891-heap.raw: 0.014219
# 2022-12-08 11:26:13.046641:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9966-1650981891-heap.raw: 0.017152
# 2022-12-08 11:26:13.061119:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9969-1650981891-heap.raw: 0.014429
# 2022-12-08 11:26:13.075343:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9972-1650981891-heap.raw: 0.014181
# 2022-12-08 11:26:13.089481:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9975-1650981891-heap.raw: 0.014091
# 2022-12-08 11:26:13.104248:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9978-1650981891-heap.raw: 0.014724
# 2022-12-08 11:26:13.121482:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9981-1650981891-heap.raw: 0.017141
# 2022-12-08 11:26:13.137761:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9984-1650981891-heap.raw: 0.016226
# 2022-12-08 11:26:13.151866:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9987-1650981891-heap.raw: 0.014052
# 2022-12-08 11:26:13.167248:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9990-1650981891-heap.raw: 0.015334
# 2022-12-08 11:26:13.187980:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9993-1650981891-heap.raw: 0.020679
# 2022-12-08 11:26:13.202835:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9996-1650981891-heap.raw: 0.014815
# 2022-12-08 11:26:13.217143:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9999-1650981891-heap.raw: 0.014249

# %%
close() # Close the logging file pointers

# %%
key_paths
# Out:
# []
