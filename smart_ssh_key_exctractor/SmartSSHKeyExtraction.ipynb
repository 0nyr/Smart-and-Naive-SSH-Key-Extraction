# %% [markdown]
# # Smart SSH Key Extractor

# %%
import os
import time
import numpy as np
from utils import print_, init, close, get_dataset_file_paths, load_models, read_key_files
import utils
from timeit import default_timer as timer
init() # Initialize the logging files

# %%
# program parameters
from dataclasses import dataclass

@dataclass
class ProgramParameters:
    DEPLOY = True # Sets the execution to deploy mode. Does not require key files

    OUTPUT_DIR_PATH = os.environ['HOME'] + "/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_exctractor/out"
    DATASET_DIR_PATH = os.environ['HOME'] + '/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/'  # TODO: ???

    def __init__(self, **kwargs):
        if (
            utils.check_path_exists(self.OUTPUT_DIR_PATH) and
            utils.check_path_exists(self.DATASET_DIR_PATH)
        ):
            print("Program paths are OK.")
        else:
            print("Program paths are NOT OK.")
            exit(1)
        
        self.print_params()

    def print_params(self):
        print("Program parameters:")
        print("DEPLOY:", self.DEPLOY)
        print("OUTPUT_DIR_PATH:", self.OUTPUT_DIR_PATH)
        print("DATASET_DIR_PATH:", self.DATASET_DIR_PATH)

PARAMS = ProgramParameters()
# Out:
# Program paths are OK.
# Program parameters:
# DEPLOY: True
# OUTPUT_DIR_PATH: /home/onyr/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_exctractor/out
# DATASET_DIR_PATH: /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/

# %% [markdown]
# ## Functions

# %%
def get_run_length_encoded(data_block: np.ndarray):
    """
    Takes a data block of characters.
    Determine for each character the number of consecutive characters.
    Returns the list of single characters and their associated following number
    in the original data block.

    Example:
        data_block = [a,a,a,a,b,b,c,a,a]
        characters = [a,b,c,a]
        counts = [4,2,1,2]
    """

    idx = 1
    characters = []
    counts = []
    count = 1
    curr_char = data_block[0]
    while idx < len(data_block):
        if data_block[idx] == curr_char:
            idx += 1
            count += 1
            continue

        else:
            characters.append(curr_char)
            counts.append(count)

            count = 1
            curr_char = data_block[idx]

        idx += 1

    # Append the last character and count
    characters.append(curr_char)
    counts.append(count)

    return bytearray(characters), counts

# %%
def generate_rle_representation(data):
    reshaped = np.reshape(data, newshape=(int(len(data) / 8), 8))

    # Here we take reshaped array and compute the numerical row and column wise gradient and count the number
    # of zeroes in each row. If there are more than 4 zeros which means there is a pattern repeating and
    # is not a key. This is a very conservative estimate for better recall
    num_row = int(len(data) / 8)

    # x_grad = np.abs(np.diff(reshaped.astype(int), axis=1, append=np.zeros((num_row, 1)))).astype(bool)
    # y_grad = np.abs(np.diff(reshaped.astype(int), axis=0, append=np.zeros((1, 8)))).astype(bool)
    # The above numerical gradient computation is transformed into a single step below

    poss_key_locs = (np.count_nonzero(np.abs(np.diff(reshaped.astype(int), axis=1,
                                                     append=np.zeros((num_row, 1)))).astype(bool) &
                                      np.abs(np.diff(reshaped.astype(int), axis=0,
                                                     append=np.zeros((1, 8)))).astype(bool),
                                      axis=1) >= 4).astype(int)  # Changed from 4 to 3 to accommodate for 12 byte keys

    # This part addresses the issue of 12 byte keys. There could be two identical characters next to each other in the
    # last 4 bytes which would make it impossible for a key loc. We modify that if there is a possibility for a key
    idx = 1
    while idx < len(poss_key_locs):
        # Last 4 characters must be zeros and first four should have at least 3 unique characters
        if poss_key_locs[idx] == 0 and poss_key_locs[idx-1] == 1 and \
                all(reshaped[idx][4:]) == 0 and len(set(reshaped[idx][:4])) > 2:
            poss_key_locs[idx] = 1
        idx += 1

    # Roll the data to the left
    rolled = np.roll(poss_key_locs, -1)
    # The key cannot start at the last byte and then the block contain the whole key.
    # So the last value is set to False
    rolled[-1] = False
    poss_key_locs = (poss_key_locs & rolled).astype(int)

    # Roll right and OR it. The whole operation is similar to the opening morphological operation
    rolled = np.roll(poss_key_locs, 1)
    rolled[0] = False

    poss_key_locs = poss_key_locs | rolled

    characters, counts = get_run_length_encoded(poss_key_locs)

    cum_sum = [0]

    for idx in range(len(counts)):
        cum_sum.append(cum_sum[idx] + counts[idx])

    cum_sum = [x * 8 for x in cum_sum] # TODO: ???

    # The last offset is not required for the cumulative sum
    return characters, counts, cum_sum[:-1]

# %%
def get_slices(data, offsets, keys, max_key_size=128, deploy=False):
    data_blocks = []
    labels = []
    last_frame_added = False
    key_count = [0] * len(keys)
    for offset in offsets:
        if offset + max_key_size > len(data):
            curr_data = data[-max_key_size:]
            last_frame_added = True
        else:
            curr_data = data[offset:offset+max_key_size]
        data_blocks.append(curr_data)
        
        if deploy is True:
            labels.append(0)
            continue
            
        found = [l_idx for l_idx in range(len(keys)) if keys[l_idx] in curr_data]

        if len(found) > 0:
            labels.append(1)
            for key_idx in set(found):
                key_count[key_idx] += 1

        else:
            labels.append(0)

        if last_frame_added is True:
            break
    
    if deploy is False:
        assert len(data_blocks) == len(labels)
        assert sum(labels) > 0 and sum(labels) >= len(keys)
        assert min(key_count) != 0
    return data_blocks, labels

# %%
def build_encoded_dataset(heap_paths, key_paths, max_key_size=128, deploy=False):

    dataset = []
    labels = []
    for heap_path, key_path in zip(heap_paths, key_paths):

        # Check if the key path corresponds to the heap path, then read the required data
        curr_keys = ['EMPTY KEYS']
        if deploy is False:
            assert (key_path[:-5] in heap_path)
            curr_keys = read_key_files(key_path)
            # Remove repeated keys. This is an issue for some older versions of OpenSSH
            curr_keys = list(map(bytearray, set(tuple(x) for x in curr_keys)))

        with open(heap_path, "rb") as fp:
            data = bytearray(fp.read())
            
        characters, counts, cum_sum = generate_rle_representation(data)
        
        viable_offsets = [cum_sum[idx] for idx in range(len(cum_sum)) if characters[idx] == 1]
        slices, curr_labels = get_slices(data=data, offsets=viable_offsets, max_key_size=max_key_size, 
                                         keys=curr_keys, deploy=deploy)
        dataset = dataset + slices
        labels = labels + curr_labels

    assert len(labels) == len(dataset)
    return dataset, labels

# %%
def generate_probable_slices(clf, heap_paths, key_paths, params: ProgramParameters):
    # Sort the heap paths and key paths, so it easier to group them by version and key length
    heap_paths.sort()
    key_paths.sort()
    
    # For each of the keys
    for idx in range(len(heap_paths)):
        start = time.time()
        key_path = ['EMPTY STRING']
        if params.DEPLOY is False:
            key_path = [key_paths[idx]]
            
        dataset, curr_labels = build_encoded_dataset(
            heap_paths=[heap_paths[idx]],
            key_paths=key_path, 
            deploy=params.DEPLOY
        )

        x_test = np.array(dataset).astype(int)
        curr_pred = clf.predict(x_test)

        path_idx = heap_paths[idx].rfind("/")
        file_name = heap_paths[idx][path_idx+1:-3] + "txt"
        sub_dir = heap_paths[idx][len(params.DATASET_DIR_PATH)+1:path_idx]
        dir_path = os.path.join(params.OUTPUT_DIR_PATH, sub_dir)
        path = os.path.join(dir_path, file_name)
        if os.path.exists(dir_path) is False:
            os.makedirs(dir_path)

        with open(path, 'w') as fp:
            for inner_idx, pred in enumerate(curr_pred):
                if pred == 0:
                    continue

                temp = ''.join(format(x, '02x') for x in dataset[inner_idx])
                fp.write(temp + "\n")

        end = time.time()
        print_('Total time taken for file %s: %f' % (heap_paths[idx], (end - start)))

# %% [markdown]
# ## Execution

# %%
# Load the models
clf = load_models(load_high_recall_only=True)
# Out:
# 2022-12-08 10:05:06.672601:	Time taken for loading high recall classifier: 0.018918

# %%
# Search for all the files with in the test directory
# start = time.time()
start = timer()
heap_paths, key_paths = get_dataset_file_paths(PARAMS.DATASET_DIR_PATH, deploy=PARAMS.DEPLOY)
end = timer()
# end = time.time()
print_('Time taken for finding all files: %f' % (end - start))

# print first 5 values in heap_paths
print("heap_paths:", heap_paths[:5])
print("key_paths:", key_paths[:5])
# Out:
# 2022-12-08 10:05:06.714110:	Time taken for finding all files: 0.003997
# heap_paths: ['/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw']
# key_paths: []

# %%
generate_probable_slices(clf=clf, heap_paths=heap_paths, key_paths=key_paths, params=PARAMS)
# Out:
# 2022-12-08 10:05:06.770819:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10237-1650982250-heap.raw: 0.019553
# 2022-12-08 10:05:06.789341:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10240-1650982250-heap.raw: 0.018430
# 2022-12-08 10:05:06.806727:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10243-1650982250-heap.raw: 0.017321
# 2022-12-08 10:05:06.821721:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10246-1650982250-heap.raw: 0.014941
# 2022-12-08 10:05:06.836800:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10249-1650982250-heap.raw: 0.015029
# 2022-12-08 10:05:06.852878:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10252-1650982250-heap.raw: 0.016033
# 2022-12-08 10:05:06.868157:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10255-1650982250-heap.raw: 0.015216
# 2022-12-08 10:05:06.883450:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10258-1650982250-heap.raw: 0.015251
# 2022-12-08 10:05:06.902472:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10261-1650982250-heap.raw: 0.018931
# 2022-12-08 10:05:06.920765:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10264-1650982250-heap.raw: 0.018238
# 2022-12-08 10:05:06.937190:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10267-1650982250-heap.raw: 0.016310
# 2022-12-08 10:05:06.952499:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10270-1650982250-heap.raw: 0.015261
# 2022-12-08 10:05:06.968524:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10273-1650982250-heap.raw: 0.015980
# 2022-12-08 10:05:06.982969:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10276-1650982250-heap.raw: 0.014399
# 2022-12-08 10:05:06.997513:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10279-1650982250-heap.raw: 0.014448
# 2022-12-08 10:05:07.010551:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10282-1650982250-heap.raw: 0.013004
# 2022-12-08 10:05:07.024892:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10285-1650982250-heap.raw: 0.014298
# 2022-12-08 10:05:07.038548:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10288-1650982250-heap.raw: 0.013613
# 2022-12-08 10:05:07.052630:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10291-1650982250-heap.raw: 0.014045
# 2022-12-08 10:05:07.066952:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10294-1650982250-heap.raw: 0.014283
# 2022-12-08 10:05:07.080566:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10297-1650982250-heap.raw: 0.013571
# 2022-12-08 10:05:07.095555:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10300-1650982250-heap.raw: 0.014948
# 2022-12-08 10:05:07.109523:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10303-1650982250-heap.raw: 0.013902
# 2022-12-08 10:05:07.124398:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10306-1650982250-heap.raw: 0.014843
# 2022-12-08 10:05:07.138304:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10309-1650982250-heap.raw: 0.013861
# 2022-12-08 10:05:07.152574:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10312-1650982250-heap.raw: 0.014238
# 2022-12-08 10:05:07.166331:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10315-1650982250-heap.raw: 0.013722
# 2022-12-08 10:05:07.180448:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10318-1650982250-heap.raw: 0.014082
# 2022-12-08 10:05:07.195239:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10321-1650982250-heap.raw: 0.014754
# 2022-12-08 10:05:07.209929:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10324-1650982250-heap.raw: 0.014628
# 2022-12-08 10:05:07.225570:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10327-1650982250-heap.raw: 0.015593
# 2022-12-08 10:05:07.240886:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10330-1650982250-heap.raw: 0.015265
# 2022-12-08 10:05:07.256557:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10333-1650982250-heap.raw: 0.015619
# 2022-12-08 10:05:07.272262:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10336-1650982250-heap.raw: 0.015655
# 2022-12-08 10:05:07.288157:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10339-1650982250-heap.raw: 0.015847
# 2022-12-08 10:05:07.304264:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10342-1650982250-heap.raw: 0.016059
# 2022-12-08 10:05:07.320276:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10345-1650982250-heap.raw: 0.015903
# 2022-12-08 10:05:07.335766:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10348-1650982250-heap.raw: 0.015434
# 2022-12-08 10:05:07.350242:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10351-1650982250-heap.raw: 0.014390
# 2022-12-08 10:05:07.364227:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10354-1650982250-heap.raw: 0.013946
# 2022-12-08 10:05:07.378014:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10357-1650982250-heap.raw: 0.013751
# 2022-12-08 10:05:07.391886:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10360-1650982250-heap.raw: 0.013833
# 2022-12-08 10:05:07.406396:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10363-1650982250-heap.raw: 0.014448
# 2022-12-08 10:05:07.420756:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10366-1650982250-heap.raw: 0.014285
# 2022-12-08 10:05:07.434539:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10370-1650982250-heap.raw: 0.013743
# 2022-12-08 10:05:07.448664:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10373-1650982250-heap.raw: 0.014088
# 2022-12-08 10:05:07.462891:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10376-1650982250-heap.raw: 0.014184
# 2022-12-08 10:05:07.478186:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10379-1650982250-heap.raw: 0.015256
# 2022-12-08 10:05:07.492635:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10382-1650982250-heap.raw: 0.014410
# 2022-12-08 10:05:07.507111:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10385-1650982250-heap.raw: 0.014434
# 2022-12-08 10:05:07.526545:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10388-1650982250-heap.raw: 0.019368
# 2022-12-08 10:05:07.541292:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10391-1650982250-heap.raw: 0.014710
# 2022-12-08 10:05:07.556512:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10394-1650982250-heap.raw: 0.015136
# 2022-12-08 10:05:07.571206:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10397-1650982250-heap.raw: 0.014643
# 2022-12-08 10:05:07.589553:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10400-1650982250-heap.raw: 0.018299
# 2022-12-08 10:05:07.604710:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10403-1650982250-heap.raw: 0.015117
# 2022-12-08 10:05:07.622624:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10406-1650982250-heap.raw: 0.017868
# 2022-12-08 10:05:07.639844:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10409-1650982250-heap.raw: 0.017136
# 2022-12-08 10:05:07.658911:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10412-1650982250-heap.raw: 0.019022
# 2022-12-08 10:05:07.675373:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10415-1650982250-heap.raw: 0.016412
# 2022-12-08 10:05:07.695924:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10418-1650982250-heap.raw: 0.020498
# 2022-12-08 10:05:07.716887:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10421-1650982250-heap.raw: 0.020911
# 2022-12-08 10:05:07.737550:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10424-1650982250-heap.raw: 0.020574
# 2022-12-08 10:05:07.755710:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10427-1650982250-heap.raw: 0.018115
# 2022-12-08 10:05:07.773843:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10430-1650982250-heap.raw: 0.018037
# 2022-12-08 10:05:07.792181:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10433-1650982250-heap.raw: 0.018298
# 2022-12-08 10:05:07.810065:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10436-1650982250-heap.raw: 0.017838
# 2022-12-08 10:05:07.829876:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10439-1650982250-heap.raw: 0.019761
# 2022-12-08 10:05:07.844475:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10442-1650982250-heap.raw: 0.014510
# 2022-12-08 10:05:07.861713:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10445-1650982250-heap.raw: 0.017201
# 2022-12-08 10:05:07.876697:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10448-1650982250-heap.raw: 0.014941
# 2022-12-08 10:05:07.891666:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10451-1650982250-heap.raw: 0.014924
# 2022-12-08 10:05:07.906406:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10454-1650982250-heap.raw: 0.014694
# 2022-12-08 10:05:07.922028:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10457-1650982250-heap.raw: 0.015579
# 2022-12-08 10:05:07.937122:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10460-1650982250-heap.raw: 0.015003
# 2022-12-08 10:05:07.951140:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10463-1650982250-heap.raw: 0.013980
# 2022-12-08 10:05:07.966165:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10466-1650982250-heap.raw: 0.014991
# 2022-12-08 10:05:07.980753:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10469-1650982250-heap.raw: 0.014521
# 2022-12-08 10:05:07.995099:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10472-1650982250-heap.raw: 0.014307
# 2022-12-08 10:05:08.009308:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10475-1650982250-heap.raw: 0.014169
# 2022-12-08 10:05:08.023516:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10478-1650982250-heap.raw: 0.014161
# 2022-12-08 10:05:08.038202:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10481-1650982250-heap.raw: 0.014652
# 2022-12-08 10:05:08.052800:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10484-1650982250-heap.raw: 0.014536
# 2022-12-08 10:05:08.067413:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10487-1650982250-heap.raw: 0.014567
# 2022-12-08 10:05:08.081791:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10490-1650982250-heap.raw: 0.014336
# 2022-12-08 10:05:08.096534:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10493-1650982250-heap.raw: 0.014703
# 2022-12-08 10:05:08.112556:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10496-1650982250-heap.raw: 0.015954
# 2022-12-08 10:05:08.128432:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10499-1650982250-heap.raw: 0.015834
# 2022-12-08 10:05:08.142570:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10502-1650982250-heap.raw: 0.014081
# 2022-12-08 10:05:08.157072:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10505-1650982250-heap.raw: 0.014462
# 2022-12-08 10:05:08.171273:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10508-1650982250-heap.raw: 0.014157
# 2022-12-08 10:05:08.186848:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10511-1650982250-heap.raw: 0.015518
# 2022-12-08 10:05:08.200896:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10514-1650982250-heap.raw: 0.014009
# 2022-12-08 10:05:08.219165:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10517-1650982250-heap.raw: 0.018233
# 2022-12-08 10:05:08.235182:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10520-1650982250-heap.raw: 0.015978
# 2022-12-08 10:05:08.252270:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10523-1650982250-heap.raw: 0.017049
# 2022-12-08 10:05:08.268885:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10526-1650982250-heap.raw: 0.016530
# 2022-12-08 10:05:08.285271:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10529-1650982250-heap.raw: 0.016339
# 2022-12-08 10:05:08.300784:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10532-1650982250-heap.raw: 0.015472
# 2022-12-08 10:05:08.315239:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10535-1650982250-heap.raw: 0.014410
# 2022-12-08 10:05:08.328974:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10538-1650982549-heap.raw: 0.013693
# 2022-12-08 10:05:08.345288:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10541-1650982549-heap.raw: 0.016274
# 2022-12-08 10:05:08.361572:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10544-1650982549-heap.raw: 0.016196
# 2022-12-08 10:05:08.378126:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10547-1650982549-heap.raw: 0.016518
# 2022-12-08 10:05:08.393128:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10550-1650982549-heap.raw: 0.014948
# 2022-12-08 10:05:08.408188:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10553-1650982549-heap.raw: 0.015011
# 2022-12-08 10:05:08.422468:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10556-1650982549-heap.raw: 0.014238
# 2022-12-08 10:05:08.436488:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10559-1650982549-heap.raw: 0.013981
# 2022-12-08 10:05:08.450848:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10562-1650982549-heap.raw: 0.014319
# 2022-12-08 10:05:08.464917:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10565-1650982549-heap.raw: 0.014027
# 2022-12-08 10:05:08.480220:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10568-1650982549-heap.raw: 0.015192
# 2022-12-08 10:05:08.494087:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10571-1650982549-heap.raw: 0.013831
# 2022-12-08 10:05:08.508459:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10574-1650982549-heap.raw: 0.014326
# 2022-12-08 10:05:08.522603:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10577-1650982549-heap.raw: 0.014102
# 2022-12-08 10:05:08.536437:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10580-1650982549-heap.raw: 0.013799
# 2022-12-08 10:05:08.552046:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw: 0.015571
# 2022-12-08 10:05:08.565764:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10586-1650982549-heap.raw: 0.013667
# 2022-12-08 10:05:08.583013:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10589-1650982549-heap.raw: 0.017215
# 2022-12-08 10:05:08.597061:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10592-1650982549-heap.raw: 0.013993
# 2022-12-08 10:05:08.611787:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10595-1650982549-heap.raw: 0.014684
# 2022-12-08 10:05:08.625947:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10598-1650982549-heap.raw: 0.014117
# 2022-12-08 10:05:08.640350:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10601-1650982549-heap.raw: 0.014362
# 2022-12-08 10:05:08.654253:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10607-1650982549-heap.raw: 0.013865
# 2022-12-08 10:05:08.668547:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10610-1650982549-heap.raw: 0.014262
# 2022-12-08 10:05:08.683186:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10613-1650982549-heap.raw: 0.014592
# 2022-12-08 10:05:08.697698:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10616-1650982549-heap.raw: 0.014474
# 2022-12-08 10:05:08.711909:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10619-1650982549-heap.raw: 0.014173
# 2022-12-08 10:05:08.725909:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10622-1650982549-heap.raw: 0.013960
# 2022-12-08 10:05:08.740540:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10625-1650982549-heap.raw: 0.014588
# 2022-12-08 10:05:08.755048:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10628-1650982549-heap.raw: 0.014462
# 2022-12-08 10:05:08.770571:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10631-1650982549-heap.raw: 0.015401
# 2022-12-08 10:05:08.785298:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10634-1650982549-heap.raw: 0.014696
# 2022-12-08 10:05:08.800519:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10637-1650982549-heap.raw: 0.015172
# 2022-12-08 10:05:08.814806:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10640-1650982549-heap.raw: 0.014247
# 2022-12-08 10:05:08.830477:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10643-1650982549-heap.raw: 0.015628
# 2022-12-08 10:05:08.845176:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10646-1650982549-heap.raw: 0.014661
# 2022-12-08 10:05:08.859893:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10649-1650982549-heap.raw: 0.014678
# 2022-12-08 10:05:08.875027:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10652-1650982549-heap.raw: 0.015090
# 2022-12-08 10:05:08.889346:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10655-1650982549-heap.raw: 0.014248
# 2022-12-08 10:05:08.904913:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10658-1650982549-heap.raw: 0.015526
# 2022-12-08 10:05:08.918309:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10661-1650982549-heap.raw: 0.013365
# 2022-12-08 10:05:08.932263:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10664-1650982549-heap.raw: 0.013919
# 2022-12-08 10:05:08.945647:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10667-1650982549-heap.raw: 0.013354
# 2022-12-08 10:05:08.960552:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10670-1650982549-heap.raw: 0.014872
# 2022-12-08 10:05:08.974674:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10673-1650982549-heap.raw: 0.014063
# 2022-12-08 10:05:08.989580:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10676-1650982549-heap.raw: 0.014865
# 2022-12-08 10:05:09.004682:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10679-1650982549-heap.raw: 0.015025
# 2022-12-08 10:05:09.018400:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10682-1650982549-heap.raw: 0.013684
# 2022-12-08 10:05:09.032707:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10685-1650982549-heap.raw: 0.014275
# 2022-12-08 10:05:09.046094:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10688-1650982549-heap.raw: 0.013352
# 2022-12-08 10:05:09.062251:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10691-1650982549-heap.raw: 0.016120
# 2022-12-08 10:05:09.081891:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10694-1650982549-heap.raw: 0.019599
# 2022-12-08 10:05:09.096165:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10697-1650982549-heap.raw: 0.014223
# 2022-12-08 10:05:09.110076:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10700-1650982549-heap.raw: 0.013872
# 2022-12-08 10:05:09.124480:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10703-1650982549-heap.raw: 0.014361
# 2022-12-08 10:05:09.138680:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10706-1650982549-heap.raw: 0.014161
# 2022-12-08 10:05:09.151544:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10709-1650982549-heap.raw: 0.012832
# 2022-12-08 10:05:09.166395:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10712-1650982549-heap.raw: 0.014819
# 2022-12-08 10:05:09.180347:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10715-1650982549-heap.raw: 0.013906
# 2022-12-08 10:05:09.194965:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10718-1650982549-heap.raw: 0.014588
# 2022-12-08 10:05:09.208833:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw: 0.013821
# 2022-12-08 10:05:09.223170:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10724-1650982549-heap.raw: 0.014300
# 2022-12-08 10:05:09.237516:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10727-1650982549-heap.raw: 0.014311
# 2022-12-08 10:05:09.250501:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw: 0.012960
# 2022-12-08 10:05:09.264846:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10733-1650982549-heap.raw: 0.014309
# 2022-12-08 10:05:09.279311:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10736-1650982549-heap.raw: 0.014425
# 2022-12-08 10:05:09.294170:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10739-1650982549-heap.raw: 0.014820
# 2022-12-08 10:05:09.308818:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10742-1650982549-heap.raw: 0.014564
# 2022-12-08 10:05:09.323944:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10745-1650982549-heap.raw: 0.015081
# 2022-12-08 10:05:09.340220:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10748-1650982549-heap.raw: 0.016229
# 2022-12-08 10:05:09.353847:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10751-1650982549-heap.raw: 0.013589
# 2022-12-08 10:05:09.368578:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw: 0.014700
# 2022-12-08 10:05:09.382496:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10757-1650982549-heap.raw: 0.013876
# 2022-12-08 10:05:09.397384:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10760-1650982549-heap.raw: 0.014860
# 2022-12-08 10:05:09.411281:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10763-1650982549-heap.raw: 0.013835
# 2022-12-08 10:05:09.425698:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10766-1650982549-heap.raw: 0.014384
# 2022-12-08 10:05:09.440440:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10769-1650982549-heap.raw: 0.014698
# 2022-12-08 10:05:09.454235:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10772-1650982549-heap.raw: 0.013754
# 2022-12-08 10:05:09.468719:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10775-1650982549-heap.raw: 0.014443
# 2022-12-08 10:05:09.482616:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10778-1650982549-heap.raw: 0.013864
# 2022-12-08 10:05:09.499279:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10781-1650982549-heap.raw: 0.016634
# 2022-12-08 10:05:09.513640:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10784-1650982549-heap.raw: 0.014318
# 2022-12-08 10:05:09.527892:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10787-1650982549-heap.raw: 0.014213
# 2022-12-08 10:05:09.542483:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10790-1650982549-heap.raw: 0.014554
# 2022-12-08 10:05:09.556905:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10793-1650982549-heap.raw: 0.014379
# 2022-12-08 10:05:09.572037:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw: 0.015095
# 2022-12-08 10:05:09.585591:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10799-1650982549-heap.raw: 0.013507
# 2022-12-08 10:05:09.604387:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10802-1650982549-heap.raw: 0.018766
# 2022-12-08 10:05:09.618118:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10805-1650982549-heap.raw: 0.013684
# 2022-12-08 10:05:09.637900:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10808-1650982549-heap.raw: 0.019743
# 2022-12-08 10:05:09.651373:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10811-1650982549-heap.raw: 0.013433
# 2022-12-08 10:05:09.665717:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10814-1650982549-heap.raw: 0.014308
# 2022-12-08 10:05:09.681146:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10817-1650982549-heap.raw: 0.015383
# 2022-12-08 10:05:09.695441:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10820-1650982549-heap.raw: 0.014252
# 2022-12-08 10:05:09.710203:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10823-1650982549-heap.raw: 0.014728
# 2022-12-08 10:05:09.725054:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10826-1650982549-heap.raw: 0.014796
# 2022-12-08 10:05:09.738971:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10829-1650982549-heap.raw: 0.013879
# 2022-12-08 10:05:09.752003:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10832-1650982549-heap.raw: 0.012999
# 2022-12-08 10:05:09.766153:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10835-1650982549-heap.raw: 0.014111
# 2022-12-08 10:05:09.780092:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10838-1650982549-heap.raw: 0.013911
# 2022-12-08 10:05:09.794372:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10002-1650981891-heap.raw: 0.014228
# 2022-12-08 10:05:09.808486:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10005-1650981891-heap.raw: 0.014082
# 2022-12-08 10:05:09.822885:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10008-1650981891-heap.raw: 0.014347
# 2022-12-08 10:05:09.837278:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10011-1650981891-heap.raw: 0.014356
# 2022-12-08 10:05:09.850264:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10014-1650981891-heap.raw: 0.012952
# 2022-12-08 10:05:09.863991:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10017-1650981891-heap.raw: 0.013693
# 2022-12-08 10:05:09.877002:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10020-1650981891-heap.raw: 0.012980
# 2022-12-08 10:05:09.890863:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10023-1650981891-heap.raw: 0.013827
# 2022-12-08 10:05:09.904694:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10026-1650981891-heap.raw: 0.013792
# 2022-12-08 10:05:09.918805:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10029-1650981891-heap.raw: 0.014079
# 2022-12-08 10:05:09.933714:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10032-1650981891-heap.raw: 0.014819
# 2022-12-08 10:05:09.947635:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10035-1650981891-heap.raw: 0.013877
# 2022-12-08 10:05:09.963361:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10038-1650981891-heap.raw: 0.015683
# 2022-12-08 10:05:09.979166:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10041-1650981891-heap.raw: 0.015763
# 2022-12-08 10:05:09.994428:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10044-1650981891-heap.raw: 0.015222
# 2022-12-08 10:05:10.009596:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10047-1650981891-heap.raw: 0.015077
# 2022-12-08 10:05:10.024496:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10050-1650981891-heap.raw: 0.014839
# 2022-12-08 10:05:10.039219:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10053-1650981891-heap.raw: 0.014676
# 2022-12-08 10:05:10.053290:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10056-1650981891-heap.raw: 0.013994
# 2022-12-08 10:05:10.068026:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10059-1650981891-heap.raw: 0.014696
# 2022-12-08 10:05:10.082026:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10062-1650981891-heap.raw: 0.013963
# 2022-12-08 10:05:10.096235:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10065-1650981891-heap.raw: 0.014171
# 2022-12-08 10:05:10.110273:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10068-1650981891-heap.raw: 0.014003
# 2022-12-08 10:05:10.125878:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10071-1650981891-heap.raw: 0.015567
# 2022-12-08 10:05:10.140596:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10074-1650981891-heap.raw: 0.014634
# 2022-12-08 10:05:10.155762:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10077-1650981891-heap.raw: 0.015119
# 2022-12-08 10:05:10.173067:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10080-1650981891-heap.raw: 0.017262
# 2022-12-08 10:05:10.188211:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10083-1650981891-heap.raw: 0.015106
# 2022-12-08 10:05:10.207135:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10086-1650981891-heap.raw: 0.018879
# 2022-12-08 10:05:10.223594:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10089-1650981891-heap.raw: 0.016370
# 2022-12-08 10:05:10.239081:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10092-1650981891-heap.raw: 0.015386
# 2022-12-08 10:05:10.253852:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10095-1650981891-heap.raw: 0.014725
# 2022-12-08 10:05:10.268841:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10098-1650981891-heap.raw: 0.014946
# 2022-12-08 10:05:10.282625:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10101-1650981891-heap.raw: 0.013745
# 2022-12-08 10:05:10.297268:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10104-1650981891-heap.raw: 0.014600
# 2022-12-08 10:05:10.310649:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10107-1650981891-heap.raw: 0.013347
# 2022-12-08 10:05:10.325331:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10110-1650981891-heap.raw: 0.014646
# 2022-12-08 10:05:10.339764:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10113-1650981891-heap.raw: 0.014396
# 2022-12-08 10:05:10.354997:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10116-1650981891-heap.raw: 0.015170
# 2022-12-08 10:05:10.369574:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10119-1650981891-heap.raw: 0.014535
# 2022-12-08 10:05:10.383406:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10122-1650981891-heap.raw: 0.013796
# 2022-12-08 10:05:10.514330:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10125-1650981891-heap.raw: 0.130897
# 2022-12-08 10:05:10.531016:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10128-1650981891-heap.raw: 0.016637
# 2022-12-08 10:05:10.545379:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10131-1650981891-heap.raw: 0.014329
# 2022-12-08 10:05:10.560220:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10134-1650981891-heap.raw: 0.014790
# 2022-12-08 10:05:10.574629:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10137-1650981891-heap.raw: 0.014367
# 2022-12-08 10:05:10.588793:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10140-1650981891-heap.raw: 0.014121
# 2022-12-08 10:05:10.602811:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10143-1650981891-heap.raw: 0.013978
# 2022-12-08 10:05:10.615650:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10146-1650981891-heap.raw: 0.012805
# 2022-12-08 10:05:10.629510:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10149-1650981891-heap.raw: 0.013823
# 2022-12-08 10:05:10.642833:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10152-1650981891-heap.raw: 0.013287
# 2022-12-08 10:05:10.656664:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10155-1650981891-heap.raw: 0.013793
# 2022-12-08 10:05:10.670107:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10158-1650981891-heap.raw: 0.013406
# 2022-12-08 10:05:10.683276:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10161-1650981891-heap.raw: 0.013135
# 2022-12-08 10:05:10.697060:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10164-1650981891-heap.raw: 0.013744
# 2022-12-08 10:05:10.709967:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10167-1650981891-heap.raw: 0.012873
# 2022-12-08 10:05:10.725420:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10170-1650981891-heap.raw: 0.015421
# 2022-12-08 10:05:10.740043:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10173-1650981891-heap.raw: 0.014533
# 2022-12-08 10:05:10.755069:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10176-1650981891-heap.raw: 0.014987
# 2022-12-08 10:05:10.769839:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10179-1650981891-heap.raw: 0.014694
# 2022-12-08 10:05:10.784224:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10182-1650981891-heap.raw: 0.014348
# 2022-12-08 10:05:10.798621:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10185-1650981891-heap.raw: 0.014354
# 2022-12-08 10:05:10.811945:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10188-1650981891-heap.raw: 0.013259
# 2022-12-08 10:05:10.826469:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10191-1650981891-heap.raw: 0.014484
# 2022-12-08 10:05:10.839702:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10194-1650981891-heap.raw: 0.013200
# 2022-12-08 10:05:10.853605:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10197-1650981891-heap.raw: 0.013872
# 2022-12-08 10:05:10.866910:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10200-1650981891-heap.raw: 0.013268
# 2022-12-08 10:05:10.879940:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10203-1650981891-heap.raw: 0.013002
# 2022-12-08 10:05:10.894138:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10206-1650981891-heap.raw: 0.014162
# 2022-12-08 10:05:10.907982:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10209-1650981891-heap.raw: 0.013801
# 2022-12-08 10:05:10.922270:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10212-1650981891-heap.raw: 0.014247
# 2022-12-08 10:05:10.936824:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10215-1650981891-heap.raw: 0.014520
# 2022-12-08 10:05:10.950741:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10218-1650981891-heap.raw: 0.013842
# 2022-12-08 10:05:10.966281:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10221-1650981891-heap.raw: 0.015482
# 2022-12-08 10:05:10.980680:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10224-1650981891-heap.raw: 0.014326
# 2022-12-08 10:05:10.995547:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10227-1650981891-heap.raw: 0.014831
# 2022-12-08 10:05:11.009453:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10230-1650981891-heap.raw: 0.013868
# 2022-12-08 10:05:11.024100:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10233-1650981891-heap.raw: 0.014599
# 2022-12-08 10:05:11.037809:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9936-1650981891-heap.raw: 0.013666
# 2022-12-08 10:05:11.052216:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9939-1650981891-heap.raw: 0.014369
# 2022-12-08 10:05:11.066969:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9942-1650981891-heap.raw: 0.014711
# 2022-12-08 10:05:11.080593:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9945-1650981891-heap.raw: 0.013582
# 2022-12-08 10:05:11.095160:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9948-1650981891-heap.raw: 0.014528
# 2022-12-08 10:05:11.108592:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9951-1650981891-heap.raw: 0.013394
# 2022-12-08 10:05:11.123098:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9954-1650981891-heap.raw: 0.014466
# 2022-12-08 10:05:11.136995:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9957-1650981891-heap.raw: 0.013857
# 2022-12-08 10:05:11.152141:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9960-1650981891-heap.raw: 0.015102
# 2022-12-08 10:05:11.167097:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9963-1650981891-heap.raw: 0.014863
# 2022-12-08 10:05:11.181098:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9966-1650981891-heap.raw: 0.013950
# 2022-12-08 10:05:11.196388:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9969-1650981891-heap.raw: 0.015200
# 2022-12-08 10:05:11.210044:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9972-1650981891-heap.raw: 0.013620
# 2022-12-08 10:05:11.224855:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9975-1650981891-heap.raw: 0.014771
# 2022-12-08 10:05:11.238510:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9978-1650981891-heap.raw: 0.013618
# 2022-12-08 10:05:11.252343:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9981-1650981891-heap.raw: 0.013794
# 2022-12-08 10:05:11.266809:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9984-1650981891-heap.raw: 0.014421
# 2022-12-08 10:05:11.280265:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9987-1650981891-heap.raw: 0.013415
# 2022-12-08 10:05:11.294448:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9990-1650981891-heap.raw: 0.014143
# 2022-12-08 10:05:11.307899:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9993-1650981891-heap.raw: 0.013408
# 2022-12-08 10:05:11.322053:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9996-1650981891-heap.raw: 0.014112
# 2022-12-08 10:05:11.335721:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9999-1650981891-heap.raw: 0.013630

# %%
close() # Close the logging file pointers

# %%
key_paths
# Out:
# []
