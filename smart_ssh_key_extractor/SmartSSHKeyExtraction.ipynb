# %% [markdown]
# # Smart SSH Key Extractor

# %%
import os
import time
import numpy as np
from utils import log, get_dataset_file_paths, load_models, read_key_files
import utils
from timeit import default_timer as timer

# %%
# program parameters
from dataclasses import dataclass

@dataclass
class ProgramParameters:
    """
    Wrapper class for program parameters.
    """

    # Sets the execution to deploy mode. Does not require key files.
    # If False: We give it '.json' files with key info to check the code.
    # If True: We give no hint about the keys, and the code should find them.
    DEPLOY = True 

    OUTPUT_DIR_PATH = os.environ['HOME'] + "/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_extractor/out"
    DATASET_DIR_PATH = os.environ['HOME'] + '/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/'  # TODO: ???

    def __init__(self, **kwargs):
        if (
            utils.check_path_exists(self.OUTPUT_DIR_PATH) and
            utils.check_path_exists(self.DATASET_DIR_PATH)
        ):
            print("Program paths are OK.")
        else:
            print("Program paths are NOT OK.")
            exit(1)
        
        self.print_params()

    def print_params(self):
        print("Program parameters:")
        print("DEPLOY:", self.DEPLOY)
        print("OUTPUT_DIR_PATH:", self.OUTPUT_DIR_PATH)
        print("DATASET_DIR_PATH:", self.DATASET_DIR_PATH)

PARAMS = ProgramParameters()
# Out:
# Program paths are OK.
# Program parameters:
# DEPLOY: True
# OUTPUT_DIR_PATH: /home/onyr/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_extractor/out
# DATASET_DIR_PATH: /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/

# %% [markdown]
# ## Functions

# %%
def get_run_length_encoded(data_block: np.ndarray):
    """
    Takes a data block of bytes.
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block.

    Example:
        data_block = [a,a,a,a,b,b,c,a,a]
        byte_array = [a,b,c,a]
        counts = [4,2,1,2]
    """

    idx = 1
    byte_array = []
    counts = []
    count = 1
    curr_char = data_block[0]
    while idx < len(data_block):
        if data_block[idx] == curr_char:
            idx += 1
            count += 1
            continue

        else:
            byte_array.append(curr_char)
            counts.append(count)

            count = 1
            curr_char = data_block[idx]

        idx += 1

    # Append the last byte and count
    byte_array.append(curr_char)
    counts.append(count)

    return bytearray(byte_array), counts

# %%
def generate_rle_representation(raw_data: bytearray):
    """
    Takes a data block of bytes (NOTE: byte == octet != bit).
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block, and the cumulative sum of the counts.
    """

    reshaped = np.reshape(raw_data, newshape=(int(len(raw_data) / 8), 8))

    # Here we take reshaped array and compute the numerical row and column wise gradient and count the number
    # of zeroes in each row. If there are more than 4 zeros which means there is a pattern repeating and
    # is not a key. This is a very conservative estimate for better recall
    num_row = int(len(raw_data) / 8)

    # x_grad = np.abs(np.diff(reshaped.astype(int), axis=1, append=np.zeros((num_row, 1)))).astype(bool)
    # y_grad = np.abs(np.diff(reshaped.astype(int), axis=0, append=np.zeros((1, 8)))).astype(bool)
    # The above numerical gradient computation is transformed into a single step below

    poss_key_locs = (np.count_nonzero(np.abs(np.diff(reshaped.astype(int), axis=1,
                                                     append=np.zeros((num_row, 1)))).astype(bool) &
                                      np.abs(np.diff(reshaped.astype(int), axis=0,
                                                     append=np.zeros((1, 8)))).astype(bool),
                                      axis=1) >= 4).astype(int)  # Changed from 4 to 3 to accommodate for 12 byte keys

    # This part addresses the issue of 12 byte keys. There could be two identical byte_array next to each other in the
    # last 4 bytes which would make it impossible for a key loc. We modify that if there is a possibility for a key
    idx = 1
    while idx < len(poss_key_locs):
        # Last 4 byte_array must be zeros and first four should have at least 3 unique byte_array
        if poss_key_locs[idx] == 0 and poss_key_locs[idx-1] == 1 and \
                all(reshaped[idx][4:]) == 0 and len(set(reshaped[idx][:4])) > 2:
            poss_key_locs[idx] = 1
        idx += 1

    # Roll the data to the left
    rolled = np.roll(poss_key_locs, -1)
    # The key cannot start at the last byte and then the block contain the whole key.
    # So the last value is set to False
    rolled[-1] = False
    poss_key_locs = (poss_key_locs & rolled).astype(int)

    # Roll right and OR it. The whole operation is similar to the opening morphological operation
    rolled = np.roll(poss_key_locs, 1)
    rolled[0] = False

    poss_key_locs = poss_key_locs | rolled

    byte_array, counts = get_run_length_encoded(poss_key_locs)

    cum_sum = [0]

    for idx in range(len(counts)):
        cum_sum.append(cum_sum[idx] + counts[idx])

    cum_sum = [x * 8 for x in cum_sum] # TODO: ???

    # The last offset is not required for the cumulative sum
    return byte_array, counts, cum_sum[:-1]

# %%
def get_slices(data, offsets, keys, max_key_size=128, deploy=False):
    """
    Takes a data block and a list of offsets.
    Cut the data block at the offsets and return a list of data blocks.
    Also return for each data block
    a label indicating if it contains a key or not. If deploy is True,
    the label is always 0.

    If we test the code (deploy=False), we additionnaly tests 
    if the data block contains a key.
    """

    data_blocks = []
    labels = []
    last_frame_added = False
    key_count = [0] * len(keys)
    for offset in offsets:
        if offset + max_key_size > len(data):
            curr_data = data[-max_key_size:]
            last_frame_added = True
        else:
            curr_data = data[offset:offset+max_key_size]
        data_blocks.append(curr_data)
        
        if deploy is True:
            labels.append(0)
            continue
            
        found = [l_idx for l_idx in range(len(keys)) if keys[l_idx] in curr_data]

        if len(found) > 0:
            labels.append(1)
            for key_idx in set(found):
                key_count[key_idx] += 1

        else:
            labels.append(0)

        if last_frame_added is True:
            break
    
    if deploy is False:
        assert len(data_blocks) == len(labels)
        assert sum(labels) > 0 and sum(labels) >= len(keys)
        assert min(key_count) != 0
    
    return data_blocks, labels

# %%
def build_encoded_dataset(heap_paths, key_paths, max_key_size=128, deploy=False):
    """
    Takes a list of heap paths and a list of key paths.
    For each heap path, it reads the heap file and the corresponding key file.
    It then generates a list of data blocks and a list of labels.
    The data blocks are generated by cutting the heap file at the offsets
    where a key is likely to be found. The labels indicate if the data block
    is sure to contains a key or not (when anotation is provided (deploy == False)).

    Returns a list of data blocks and a list of labels.
    """

    dataset = []
    labels = []
    for heap_path, key_path in zip(heap_paths, key_paths):

        # Check if the key path corresponds to the heap path, then read the required data
        curr_keys = ['EMPTY KEYS']
        if deploy is False:
            assert (key_path.replace(".json", "-heap.raw") == heap_path)
            curr_keys = read_key_files(key_path)
            # Remove repeated keys. This is an issue for some older versions of OpenSSH
            curr_keys = list(map(bytearray, set(tuple(x) for x in curr_keys)))

        with open(heap_path, "rb") as fp:
            data = bytearray(fp.read())
            
        byte_array, counts, cum_sum = generate_rle_representation(data)
        
        # a key can only starts with a byte of value 1, example: 00000001 10100111 101011001 ...
        viable_offsets = [cum_sum[idx] for idx in range(len(cum_sum)) if byte_array[idx] == 1]
        slices, curr_labels = get_slices(
            data=data, 
            offsets=viable_offsets, 
            max_key_size=max_key_size, 
            keys=curr_keys, 
            deploy=deploy
        )
        dataset.extend(slices)
        labels.extend(curr_labels)

    assert len(labels) == len(dataset)

    return dataset, labels

# %%
def generate_probable_slices(clf, heap_paths, key_paths, params: ProgramParameters):
    # Sort the heap paths and key paths, so it easier to group them by version and key length
    heap_paths.sort()
    key_paths.sort()
    
    # For each of the keys
    for idx in range(len(heap_paths)):
        start = time.time()

        key_path: str = ""
        if params.DEPLOY is False:
            key_path = key_paths[idx]
            
        dataset, curr_labels = build_encoded_dataset(
            heap_paths=[heap_paths[idx]],
            key_paths=[key_path], 
            deploy=params.DEPLOY
        )

        x_test = np.array(dataset).astype(int)
        curr_pred = clf.predict(x_test) # Make predictions

        # path manipulation to tranform input file paths to output file paths
        # example: transform "$INPUT/lastdir/heap.raw" to "$OUTPUT/lastdir/heap.txt
        file_name = os.path.basename(heap_paths[idx])
        file_name = file_name.replace(".raw", ".txt")
        sub_dir = os.path.dirname(heap_paths[idx]).split("/")[-1]
        dir_path = os.path.join(params.OUTPUT_DIR_PATH, sub_dir)
        output_path = os.path.join(dir_path, file_name)

        if os.path.exists(dir_path) is False:
            os.makedirs(dir_path)

        with open(output_path, 'w') as file:
            for inner_idx, pred in enumerate(curr_pred):
                # save if prediction not 0
                if pred != 0:
                    # format block to two digit hex
                    temp = ''.join(format(x, '02x') for x in dataset[inner_idx])
                    file.write(temp + "\n")

        end = time.time()
        log('Total time taken for file %s: %f' % (heap_paths[idx], (end - start)))

# %% [markdown]
# ## Execution

# %%
# Load the models
clf = load_models(load_high_recall_only=True)

# assert clf is a WrappedClassifier
assert(type(clf) == WrappedClassifier) # TODO: complete there
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 # Load the models
# ----> 2 clf = load_models(load_high_recall_only=True)
#       4 # assert clf is not None
#
# NameError: name 'load_models' is not defined

# %%
# Search for all the files with in the test directory
# start = time.time()
start = timer()
heap_paths, key_paths = get_dataset_file_paths(PARAMS.DATASET_DIR_PATH, deploy=PARAMS.DEPLOY)
end = timer()
# end = time.time()
log('Time taken for finding all files: %f' % (end - start))

# print first 5 values in heap_paths
print("heap_paths:", heap_paths[:5])
print("key_paths:", key_paths[:5])
# Out:
# 2022-12-08 11:39:47.838284:	Time taken for finding all files: 0.002707
# heap_paths: ['/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10240-1650982250-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10439-1650982250-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10276-1650982250-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10508-1650982250-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10373-1650982250-heap.raw']
# key_paths: []

# %%
generate_probable_slices(clf=clf, heap_paths=heap_paths, key_paths=key_paths, params=PARAMS)
# Out:
# 2022-12-08 11:39:47.885807:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10237-1650982250-heap.raw: 0.014115
# 2022-12-08 11:39:47.898460:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10240-1650982250-heap.raw: 0.012598
# 2022-12-08 11:39:47.910972:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10243-1650982250-heap.raw: 0.012482
# 2022-12-08 11:39:47.923280:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10246-1650982250-heap.raw: 0.012280
# 2022-12-08 11:39:47.935467:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10249-1650982250-heap.raw: 0.012161
# 2022-12-08 11:39:47.947584:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10252-1650982250-heap.raw: 0.012091
# 2022-12-08 11:39:47.960049:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10255-1650982250-heap.raw: 0.012437
# 2022-12-08 11:39:47.972238:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10258-1650982250-heap.raw: 0.012161
# 2022-12-08 11:39:47.984186:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10261-1650982250-heap.raw: 0.011921
# 2022-12-08 11:39:47.996465:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10264-1650982250-heap.raw: 0.012249
# 2022-12-08 11:39:48.009058:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10267-1650982250-heap.raw: 0.012562
# 2022-12-08 11:39:48.021751:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10270-1650982250-heap.raw: 0.012670
# 2022-12-08 11:39:48.034467:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10273-1650982250-heap.raw: 0.012653
# 2022-12-08 11:39:48.046908:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10276-1650982250-heap.raw: 0.012409
# 2022-12-08 11:39:48.059089:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10279-1650982250-heap.raw: 0.012125
# 2022-12-08 11:39:48.071251:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10282-1650982250-heap.raw: 0.012133
# 2022-12-08 11:39:48.083076:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10285-1650982250-heap.raw: 0.011797
# 2022-12-08 11:39:48.095615:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10288-1650982250-heap.raw: 0.012517
# 2022-12-08 11:39:48.107894:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10291-1650982250-heap.raw: 0.012226
# 2022-12-08 11:39:48.119997:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10294-1650982250-heap.raw: 0.012077
# 2022-12-08 11:39:48.132233:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10297-1650982250-heap.raw: 0.012209
# 2022-12-08 11:39:48.144148:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10300-1650982250-heap.raw: 0.011888
# 2022-12-08 11:39:48.156234:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10303-1650982250-heap.raw: 0.012057
# 2022-12-08 11:39:48.168304:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10306-1650982250-heap.raw: 0.012043
# 2022-12-08 11:39:48.180409:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10309-1650982250-heap.raw: 0.012075
# 2022-12-08 11:39:48.192978:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10312-1650982250-heap.raw: 0.012534
# 2022-12-08 11:39:48.205731:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10315-1650982250-heap.raw: 0.012717
# 2022-12-08 11:39:48.218099:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10318-1650982250-heap.raw: 0.012340
# 2022-12-08 11:39:48.231044:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10321-1650982250-heap.raw: 0.012914
# 2022-12-08 11:39:48.243550:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10324-1650982250-heap.raw: 0.012449
# 2022-12-08 11:39:48.256190:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10327-1650982250-heap.raw: 0.012606
# 2022-12-08 11:39:48.268956:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10330-1650982250-heap.raw: 0.012696
# 2022-12-08 11:39:48.281529:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10333-1650982250-heap.raw: 0.012540
# 2022-12-08 11:39:48.293972:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10336-1650982250-heap.raw: 0.012409
# 2022-12-08 11:39:48.306605:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10339-1650982250-heap.raw: 0.012601
# 2022-12-08 11:39:48.320342:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10342-1650982250-heap.raw: 0.013675
# 2022-12-08 11:39:48.332790:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10345-1650982250-heap.raw: 0.012417
# 2022-12-08 11:39:48.344908:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10348-1650982250-heap.raw: 0.012086
# 2022-12-08 11:39:48.357419:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10351-1650982250-heap.raw: 0.012478
# 2022-12-08 11:39:48.369878:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10354-1650982250-heap.raw: 0.012426
# 2022-12-08 11:39:48.382004:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10357-1650982250-heap.raw: 0.012093
# 2022-12-08 11:39:48.394510:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10360-1650982250-heap.raw: 0.012475
# 2022-12-08 11:39:48.406740:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10363-1650982250-heap.raw: 0.012186
# 2022-12-08 11:39:48.418814:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10366-1650982250-heap.raw: 0.012026
# 2022-12-08 11:39:48.431070:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10370-1650982250-heap.raw: 0.012226
# 2022-12-08 11:39:48.443925:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10373-1650982250-heap.raw: 0.012823
# 2022-12-08 11:39:48.456441:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10376-1650982250-heap.raw: 0.012457
# 2022-12-08 11:39:48.469050:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10379-1650982250-heap.raw: 0.012578
# 2022-12-08 11:39:48.481483:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10382-1650982250-heap.raw: 0.012379
# 2022-12-08 11:39:48.493845:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10385-1650982250-heap.raw: 0.012332
# 2022-12-08 11:39:48.506466:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10388-1650982250-heap.raw: 0.012590
# 2022-12-08 11:39:48.518706:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10391-1650982250-heap.raw: 0.012210
# 2022-12-08 11:39:48.530999:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10394-1650982250-heap.raw: 0.012232
# 2022-12-08 11:39:48.543335:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10397-1650982250-heap.raw: 0.012305
# 2022-12-08 11:39:48.555501:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10400-1650982250-heap.raw: 0.012136
# 2022-12-08 11:39:48.567838:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10403-1650982250-heap.raw: 0.012304
# 2022-12-08 11:39:48.580131:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10406-1650982250-heap.raw: 0.012260
# 2022-12-08 11:39:48.593187:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10409-1650982250-heap.raw: 0.013018
# 2022-12-08 11:39:48.605977:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10412-1650982250-heap.raw: 0.012753
# 2022-12-08 11:39:48.618314:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10415-1650982250-heap.raw: 0.012306
# 2022-12-08 11:39:48.630708:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10418-1650982250-heap.raw: 0.012356
# 2022-12-08 11:39:48.643058:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10421-1650982250-heap.raw: 0.012312
# 2022-12-08 11:39:48.655952:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10424-1650982250-heap.raw: 0.012864
# 2022-12-08 11:39:48.669297:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10427-1650982250-heap.raw: 0.013287
# 2022-12-08 11:39:48.682234:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10430-1650982250-heap.raw: 0.012906
# 2022-12-08 11:39:48.694888:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10433-1650982250-heap.raw: 0.012597
# 2022-12-08 11:39:48.707149:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10436-1650982250-heap.raw: 0.012228
# 2022-12-08 11:39:48.719143:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10439-1650982250-heap.raw: 0.011961
# 2022-12-08 11:39:48.731571:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10442-1650982250-heap.raw: 0.012398
# 2022-12-08 11:39:48.743916:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10445-1650982250-heap.raw: 0.012291
# 2022-12-08 11:39:48.756325:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10448-1650982250-heap.raw: 0.012375
# 2022-12-08 11:39:48.768945:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10451-1650982250-heap.raw: 0.012581
# 2022-12-08 11:39:48.781382:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10454-1650982250-heap.raw: 0.012405
# 2022-12-08 11:39:48.798650:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10457-1650982250-heap.raw: 0.017232
# 2022-12-08 11:39:48.814074:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10460-1650982250-heap.raw: 0.015387
# 2022-12-08 11:39:48.826227:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10463-1650982250-heap.raw: 0.012123
# 2022-12-08 11:39:48.838453:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10466-1650982250-heap.raw: 0.012197
# 2022-12-08 11:39:48.850764:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10469-1650982250-heap.raw: 0.012284
# 2022-12-08 11:39:48.863618:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10472-1650982250-heap.raw: 0.012826
# 2022-12-08 11:39:48.875955:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10475-1650982250-heap.raw: 0.012288
# 2022-12-08 11:39:48.888690:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10478-1650982250-heap.raw: 0.012700
# 2022-12-08 11:39:48.901129:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10481-1650982250-heap.raw: 0.012389
# 2022-12-08 11:39:48.913351:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10484-1650982250-heap.raw: 0.012196
# 2022-12-08 11:39:48.925494:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10487-1650982250-heap.raw: 0.012115
# 2022-12-08 11:39:48.938510:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10490-1650982250-heap.raw: 0.012986
# 2022-12-08 11:39:48.951190:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10493-1650982250-heap.raw: 0.012624
# 2022-12-08 11:39:48.963662:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10496-1650982250-heap.raw: 0.012441
# 2022-12-08 11:39:48.976107:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10499-1650982250-heap.raw: 0.012400
# 2022-12-08 11:39:48.988351:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10502-1650982250-heap.raw: 0.012214
# 2022-12-08 11:39:49.000829:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10505-1650982250-heap.raw: 0.012448
# 2022-12-08 11:39:49.013463:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10508-1650982250-heap.raw: 0.012601
# 2022-12-08 11:39:49.025645:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10511-1650982250-heap.raw: 0.012158
# 2022-12-08 11:39:49.037797:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10514-1650982250-heap.raw: 0.012117
# 2022-12-08 11:39:49.049816:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10517-1650982250-heap.raw: 0.011994
# 2022-12-08 11:39:49.061760:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10520-1650982250-heap.raw: 0.011918
# 2022-12-08 11:39:49.074414:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10523-1650982250-heap.raw: 0.012629
# 2022-12-08 11:39:49.086708:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10526-1650982250-heap.raw: 0.012245
# 2022-12-08 11:39:49.099318:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10529-1650982250-heap.raw: 0.012581
# 2022-12-08 11:39:49.111790:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10532-1650982250-heap.raw: 0.012423
# 2022-12-08 11:39:49.124120:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10535-1650982250-heap.raw: 0.012301
# 2022-12-08 11:39:49.136470:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10538-1650982549-heap.raw: 0.012323
# 2022-12-08 11:39:49.149371:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10541-1650982549-heap.raw: 0.012873
# 2022-12-08 11:39:49.161929:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10544-1650982549-heap.raw: 0.012506
# 2022-12-08 11:39:49.174210:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10547-1650982549-heap.raw: 0.012254
# 2022-12-08 11:39:49.186355:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10550-1650982549-heap.raw: 0.012120
# 2022-12-08 11:39:49.198626:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10553-1650982549-heap.raw: 0.012253
# 2022-12-08 11:39:49.210910:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10556-1650982549-heap.raw: 0.012251
# 2022-12-08 11:39:49.223077:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10559-1650982549-heap.raw: 0.012141
# 2022-12-08 11:39:49.235296:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10562-1650982549-heap.raw: 0.012191
# 2022-12-08 11:39:49.248336:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10565-1650982549-heap.raw: 0.013008
# 2022-12-08 11:39:49.261752:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10568-1650982549-heap.raw: 0.013377
# 2022-12-08 11:39:49.276555:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10571-1650982549-heap.raw: 0.014773
# 2022-12-08 11:39:49.289446:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10574-1650982549-heap.raw: 0.012790
# 2022-12-08 11:39:49.302452:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10577-1650982549-heap.raw: 0.012974
# 2022-12-08 11:39:49.314942:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10580-1650982549-heap.raw: 0.012440
# 2022-12-08 11:39:49.327176:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw: 0.012208
# 2022-12-08 11:39:49.339749:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10586-1650982549-heap.raw: 0.012540
# 2022-12-08 11:39:49.353239:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10589-1650982549-heap.raw: 0.013459
# 2022-12-08 11:39:49.367346:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10592-1650982549-heap.raw: 0.014052
# 2022-12-08 11:39:49.379784:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10595-1650982549-heap.raw: 0.012411
# 2022-12-08 11:39:49.392336:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10598-1650982549-heap.raw: 0.012526
# 2022-12-08 11:39:49.404691:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10601-1650982549-heap.raw: 0.012328
# 2022-12-08 11:39:49.416965:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10607-1650982549-heap.raw: 0.012247
# 2022-12-08 11:39:49.428877:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10610-1650982549-heap.raw: 0.011888
# 2022-12-08 11:39:49.441257:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10613-1650982549-heap.raw: 0.012356
# 2022-12-08 11:39:49.453549:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10616-1650982549-heap.raw: 0.012268
# 2022-12-08 11:39:49.465640:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10619-1650982549-heap.raw: 0.012065
# 2022-12-08 11:39:49.478139:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10622-1650982549-heap.raw: 0.012478
# 2022-12-08 11:39:49.490872:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10625-1650982549-heap.raw: 0.012647
# 2022-12-08 11:39:49.503308:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10628-1650982549-heap.raw: 0.012405
# 2022-12-08 11:39:49.516281:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10631-1650982549-heap.raw: 0.012942
# 2022-12-08 11:39:49.528982:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10634-1650982549-heap.raw: 0.012627
# 2022-12-08 11:39:49.541495:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10637-1650982549-heap.raw: 0.012483
# 2022-12-08 11:39:49.554591:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10640-1650982549-heap.raw: 0.013070
# 2022-12-08 11:39:49.567282:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10643-1650982549-heap.raw: 0.012590
# 2022-12-08 11:39:49.580228:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10646-1650982549-heap.raw: 0.012912
# 2022-12-08 11:39:49.593062:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10649-1650982549-heap.raw: 0.012801
# 2022-12-08 11:39:49.605773:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10652-1650982549-heap.raw: 0.012680
# 2022-12-08 11:39:49.618721:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10655-1650982549-heap.raw: 0.012907
# 2022-12-08 11:39:49.631774:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10658-1650982549-heap.raw: 0.013017
# 2022-12-08 11:39:49.644241:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10661-1650982549-heap.raw: 0.012438
# 2022-12-08 11:39:49.656695:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10664-1650982549-heap.raw: 0.012425
# 2022-12-08 11:39:49.669205:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10667-1650982549-heap.raw: 0.012483
# 2022-12-08 11:39:49.682084:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10670-1650982549-heap.raw: 0.012849
# 2022-12-08 11:39:49.694539:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10673-1650982549-heap.raw: 0.012401
# 2022-12-08 11:39:49.707013:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10676-1650982549-heap.raw: 0.012447
# 2022-12-08 11:39:49.719846:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10679-1650982549-heap.raw: 0.012806
# 2022-12-08 11:39:49.732290:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10682-1650982549-heap.raw: 0.012398
# 2022-12-08 11:39:49.744378:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10685-1650982549-heap.raw: 0.012065
# 2022-12-08 11:39:49.757466:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10688-1650982549-heap.raw: 0.013061
# 2022-12-08 11:39:49.770083:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10691-1650982549-heap.raw: 0.012565
# 2022-12-08 11:39:49.782223:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10694-1650982549-heap.raw: 0.012106
# 2022-12-08 11:39:49.794822:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10697-1650982549-heap.raw: 0.012564
# 2022-12-08 11:39:49.807671:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10700-1650982549-heap.raw: 0.012815
# 2022-12-08 11:39:49.820221:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10703-1650982549-heap.raw: 0.012516
# 2022-12-08 11:39:49.832825:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10706-1650982549-heap.raw: 0.012573
# 2022-12-08 11:39:49.844806:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10709-1650982549-heap.raw: 0.011955
# 2022-12-08 11:39:49.857255:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10712-1650982549-heap.raw: 0.012427
# 2022-12-08 11:39:49.869534:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10715-1650982549-heap.raw: 0.012256
# 2022-12-08 11:39:49.881565:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10718-1650982549-heap.raw: 0.012006
# 2022-12-08 11:39:49.894154:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw: 0.012556
# 2022-12-08 11:39:49.906777:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10724-1650982549-heap.raw: 0.012574
# 2022-12-08 11:39:49.919050:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10727-1650982549-heap.raw: 0.012248
# 2022-12-08 11:39:49.931872:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw: 0.012801
# 2022-12-08 11:39:49.944367:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10733-1650982549-heap.raw: 0.012430
# 2022-12-08 11:39:49.956639:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10736-1650982549-heap.raw: 0.012245
# 2022-12-08 11:39:49.969593:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10739-1650982549-heap.raw: 0.012927
# 2022-12-08 11:39:49.981567:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10742-1650982549-heap.raw: 0.011924
# 2022-12-08 11:39:49.993804:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10745-1650982549-heap.raw: 0.012219
# 2022-12-08 11:39:50.005925:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10748-1650982549-heap.raw: 0.012097
# 2022-12-08 11:39:50.018151:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10751-1650982549-heap.raw: 0.012194
# 2022-12-08 11:39:50.030551:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw: 0.012366
# 2022-12-08 11:39:50.043010:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10757-1650982549-heap.raw: 0.012432
# 2022-12-08 11:39:50.055705:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10760-1650982549-heap.raw: 0.012666
# 2022-12-08 11:39:50.068298:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10763-1650982549-heap.raw: 0.012564
# 2022-12-08 11:39:50.080419:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10766-1650982549-heap.raw: 0.012079
# 2022-12-08 11:39:50.092930:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10769-1650982549-heap.raw: 0.012481
# 2022-12-08 11:39:50.106693:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10772-1650982549-heap.raw: 0.013729
# 2022-12-08 11:39:50.120276:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10775-1650982549-heap.raw: 0.013507
# 2022-12-08 11:39:50.133582:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10778-1650982549-heap.raw: 0.013272
# 2022-12-08 11:39:50.147146:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10781-1650982549-heap.raw: 0.013512
# 2022-12-08 11:39:50.165385:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10784-1650982549-heap.raw: 0.018146
# 2022-12-08 11:39:50.183499:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10787-1650982549-heap.raw: 0.018075
# 2022-12-08 11:39:50.199261:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10790-1650982549-heap.raw: 0.015688
# 2022-12-08 11:39:50.214114:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10793-1650982549-heap.raw: 0.014812
# 2022-12-08 11:39:50.226759:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw: 0.012616
# 2022-12-08 11:39:50.239231:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10799-1650982549-heap.raw: 0.012444
# 2022-12-08 11:39:50.252231:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10802-1650982549-heap.raw: 0.012972
# 2022-12-08 11:39:50.264685:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10805-1650982549-heap.raw: 0.012431
# 2022-12-08 11:39:50.277000:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10808-1650982549-heap.raw: 0.012284
# 2022-12-08 11:39:50.289054:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10811-1650982549-heap.raw: 0.012027
# 2022-12-08 11:39:50.301420:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10814-1650982549-heap.raw: 0.012338
# 2022-12-08 11:39:50.314287:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10817-1650982549-heap.raw: 0.012840
# 2022-12-08 11:39:50.326741:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10820-1650982549-heap.raw: 0.012407
# 2022-12-08 11:39:50.339174:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10823-1650982549-heap.raw: 0.012405
# 2022-12-08 11:39:50.352862:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10826-1650982549-heap.raw: 0.013643
# 2022-12-08 11:39:50.365640:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10829-1650982549-heap.raw: 0.012717
# 2022-12-08 11:39:50.381387:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10832-1650982549-heap.raw: 0.015706
# 2022-12-08 11:39:50.394800:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10835-1650982549-heap.raw: 0.013378
# 2022-12-08 11:39:50.407665:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10838-1650982549-heap.raw: 0.012823
# 2022-12-08 11:39:50.419991:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10002-1650981891-heap.raw: 0.012299
# 2022-12-08 11:39:50.432057:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10005-1650981891-heap.raw: 0.012041
# 2022-12-08 11:39:50.444272:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10008-1650981891-heap.raw: 0.012187
# 2022-12-08 11:39:50.456356:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10011-1650981891-heap.raw: 0.012053
# 2022-12-08 11:39:50.468643:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10014-1650981891-heap.raw: 0.012255
# 2022-12-08 11:39:50.480784:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10017-1650981891-heap.raw: 0.012113
# 2022-12-08 11:39:50.493274:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10020-1650981891-heap.raw: 0.012463
# 2022-12-08 11:39:50.505617:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10023-1650981891-heap.raw: 0.012312
# 2022-12-08 11:39:50.518629:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10026-1650981891-heap.raw: 0.012976
# 2022-12-08 11:39:50.531208:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10029-1650981891-heap.raw: 0.012521
# 2022-12-08 11:39:50.544340:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10032-1650981891-heap.raw: 0.013098
# 2022-12-08 11:39:50.558821:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10035-1650981891-heap.raw: 0.014440
# 2022-12-08 11:39:50.576660:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10038-1650981891-heap.raw: 0.017767
# 2022-12-08 11:39:50.594849:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10041-1650981891-heap.raw: 0.018142
# 2022-12-08 11:39:50.613064:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10044-1650981891-heap.raw: 0.018168
# 2022-12-08 11:39:50.631920:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10047-1650981891-heap.raw: 0.018759
# 2022-12-08 11:39:50.650612:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10050-1650981891-heap.raw: 0.018636
# 2022-12-08 11:39:50.669395:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10053-1650981891-heap.raw: 0.018722
# 2022-12-08 11:39:50.687704:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10056-1650981891-heap.raw: 0.018258
# 2022-12-08 11:39:50.705503:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10059-1650981891-heap.raw: 0.017717
# 2022-12-08 11:39:50.724750:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10062-1650981891-heap.raw: 0.019194
# 2022-12-08 11:39:50.743438:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10065-1650981891-heap.raw: 0.018598
# 2022-12-08 11:39:50.762219:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10068-1650981891-heap.raw: 0.018730
# 2022-12-08 11:39:50.780323:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10071-1650981891-heap.raw: 0.018015
# 2022-12-08 11:39:50.798472:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10074-1650981891-heap.raw: 0.018101
# 2022-12-08 11:39:50.816257:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10077-1650981891-heap.raw: 0.017741
# 2022-12-08 11:39:50.833246:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10080-1650981891-heap.raw: 0.016918
# 2022-12-08 11:39:50.845890:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10083-1650981891-heap.raw: 0.012610
# 2022-12-08 11:39:50.858607:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10086-1650981891-heap.raw: 0.012680
# 2022-12-08 11:39:50.871113:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10089-1650981891-heap.raw: 0.012471
# 2022-12-08 11:39:50.883260:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10092-1650981891-heap.raw: 0.012119
# 2022-12-08 11:39:50.895355:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10095-1650981891-heap.raw: 0.012068
# 2022-12-08 11:39:50.908014:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10098-1650981891-heap.raw: 0.012633
# 2022-12-08 11:39:50.920587:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10101-1650981891-heap.raw: 0.012540
# 2022-12-08 11:39:50.933477:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10104-1650981891-heap.raw: 0.012857
# 2022-12-08 11:39:50.946799:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10107-1650981891-heap.raw: 0.013262
# 2022-12-08 11:39:50.959939:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10110-1650981891-heap.raw: 0.013105
# 2022-12-08 11:39:50.972957:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10113-1650981891-heap.raw: 0.012988
# 2022-12-08 11:39:50.986460:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10116-1650981891-heap.raw: 0.013445
# 2022-12-08 11:39:50.999330:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10119-1650981891-heap.raw: 0.012836
# 2022-12-08 11:39:51.011587:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10122-1650981891-heap.raw: 0.012226
# 2022-12-08 11:39:51.024847:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10125-1650981891-heap.raw: 0.013230
# 2022-12-08 11:39:51.039029:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10128-1650981891-heap.raw: 0.014111
# 2022-12-08 11:39:51.051298:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10131-1650981891-heap.raw: 0.012233
# 2022-12-08 11:39:51.063490:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10134-1650981891-heap.raw: 0.012156
# 2022-12-08 11:39:51.076054:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10137-1650981891-heap.raw: 0.012531
# 2022-12-08 11:39:51.088320:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10140-1650981891-heap.raw: 0.012244
# 2022-12-08 11:39:51.100475:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10143-1650981891-heap.raw: 0.012131
# 2022-12-08 11:39:51.112838:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10146-1650981891-heap.raw: 0.012331
# 2022-12-08 11:39:51.125205:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10149-1650981891-heap.raw: 0.012334
# 2022-12-08 11:39:51.137715:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10152-1650981891-heap.raw: 0.012474
# 2022-12-08 11:39:51.151435:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10155-1650981891-heap.raw: 0.013655
# 2022-12-08 11:39:51.164212:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10158-1650981891-heap.raw: 0.012740
# 2022-12-08 11:39:51.176678:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10161-1650981891-heap.raw: 0.012429
# 2022-12-08 11:39:51.189361:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10164-1650981891-heap.raw: 0.012619
# 2022-12-08 11:39:51.202964:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10167-1650981891-heap.raw: 0.013566
# 2022-12-08 11:39:51.215409:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10170-1650981891-heap.raw: 0.012413
# 2022-12-08 11:39:51.228330:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10173-1650981891-heap.raw: 0.012888
# 2022-12-08 11:39:51.241734:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10176-1650981891-heap.raw: 0.013346
# 2022-12-08 11:39:51.254849:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10179-1650981891-heap.raw: 0.013078
# 2022-12-08 11:39:51.267492:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10182-1650981891-heap.raw: 0.012608
# 2022-12-08 11:39:51.279772:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10185-1650981891-heap.raw: 0.012249
# 2022-12-08 11:39:51.292110:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10188-1650981891-heap.raw: 0.012311
# 2022-12-08 11:39:51.304393:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10191-1650981891-heap.raw: 0.012240
# 2022-12-08 11:39:51.316577:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10194-1650981891-heap.raw: 0.012164
# 2022-12-08 11:39:51.328622:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10197-1650981891-heap.raw: 0.012014
# 2022-12-08 11:39:51.341334:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10200-1650981891-heap.raw: 0.012687
# 2022-12-08 11:39:51.354079:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10203-1650981891-heap.raw: 0.012688
# 2022-12-08 11:39:51.366811:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10206-1650981891-heap.raw: 0.012698
# 2022-12-08 11:39:51.379350:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10209-1650981891-heap.raw: 0.012515
# 2022-12-08 11:39:51.391752:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10212-1650981891-heap.raw: 0.012333
# 2022-12-08 11:39:51.404239:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10215-1650981891-heap.raw: 0.012454
# 2022-12-08 11:39:51.416613:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10218-1650981891-heap.raw: 0.012340
# 2022-12-08 11:39:51.429199:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10221-1650981891-heap.raw: 0.012561
# 2022-12-08 11:39:51.442163:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10224-1650981891-heap.raw: 0.012892
# 2022-12-08 11:39:51.454781:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10227-1650981891-heap.raw: 0.012579
# 2022-12-08 11:39:51.467551:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10230-1650981891-heap.raw: 0.012742
# 2022-12-08 11:39:51.480079:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10233-1650981891-heap.raw: 0.012491
# 2022-12-08 11:39:51.492561:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9936-1650981891-heap.raw: 0.012450
# 2022-12-08 11:39:51.504836:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9939-1650981891-heap.raw: 0.012253
# 2022-12-08 11:39:51.517259:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9942-1650981891-heap.raw: 0.012393
# 2022-12-08 11:39:51.529758:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9945-1650981891-heap.raw: 0.012471
# 2022-12-08 11:39:51.542233:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9948-1650981891-heap.raw: 0.012445
# 2022-12-08 11:39:51.554920:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9951-1650981891-heap.raw: 0.012651
# 2022-12-08 11:39:51.567741:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9954-1650981891-heap.raw: 0.012755
# 2022-12-08 11:39:51.580240:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9957-1650981891-heap.raw: 0.012464
# 2022-12-08 11:39:51.593367:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9960-1650981891-heap.raw: 0.013091
# 2022-12-08 11:39:51.606300:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9963-1650981891-heap.raw: 0.012864
# 2022-12-08 11:39:51.619441:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9966-1650981891-heap.raw: 0.013102
# 2022-12-08 11:39:51.634107:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9969-1650981891-heap.raw: 0.014627
# 2022-12-08 11:39:51.647472:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9972-1650981891-heap.raw: 0.013291
# 2022-12-08 11:39:51.660727:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9975-1650981891-heap.raw: 0.013219
# 2022-12-08 11:39:51.673736:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9978-1650981891-heap.raw: 0.012975
# 2022-12-08 11:39:51.686052:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9981-1650981891-heap.raw: 0.012282
# 2022-12-08 11:39:51.700501:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9984-1650981891-heap.raw: 0.014416
# 2022-12-08 11:39:51.714410:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9987-1650981891-heap.raw: 0.013874
# 2022-12-08 11:39:51.729364:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9990-1650981891-heap.raw: 0.014917
# 2022-12-08 11:39:51.743870:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9993-1650981891-heap.raw: 0.014461
# 2022-12-08 11:39:51.757942:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9996-1650981891-heap.raw: 0.014027
# 2022-12-08 11:39:51.771144:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9999-1650981891-heap.raw: 0.013134

# %%
close() # Close the logging file pointers

# %%
key_paths
# Out:
# []
