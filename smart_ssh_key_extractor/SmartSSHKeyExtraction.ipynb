# %% [markdown]
# # Smart SSH Key Extractor

# %%
import os
import time
import numpy as np
from utils import log, get_dataset_file_paths, load_models, read_key_files, WrappedClassifier
import utils
from timeit import default_timer as timer

# %%
# prepare cwd

# check there is "out/" folder in cwd
if not os.path.exists("out/"):
    os.makedirs("out/")

# %%
# program parameters
from dataclasses import dataclass

@dataclass
class ProgramParameters:
    """
    Wrapper class for program parameters.
    """

    # Sets the execution to deploy mode. Does not require key files.
    # If False: We give it '.json' files with key info to check the code.
    # If True: We give no hint about the keys, and the code should find them.
    DEPLOY = True 

    OUTPUT_DIR_PATH = os.environ['HOME'] + "/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_extractor/out"
    DATASET_DIR_PATH = os.environ['HOME'] + '/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/'  # TODO: ???

    def __init__(self, **kwargs):
        if (
            utils.check_path_exists(self.OUTPUT_DIR_PATH) and
            utils.check_path_exists(self.DATASET_DIR_PATH)
        ):
            print("Program paths are OK.")
        else:
            print("Program paths are NOT OK.")
            exit(1)
        
        self.print_params()

    def print_params(self):
        print("Program parameters:")
        print("DEPLOY:", self.DEPLOY)
        print("OUTPUT_DIR_PATH:", self.OUTPUT_DIR_PATH)
        print("DATASET_DIR_PATH:", self.DATASET_DIR_PATH)


PARAMS = ProgramParameters()
# Out:
# Program paths are OK.
# Program parameters:
# DEPLOY: True
# OUTPUT_DIR_PATH: /home/onyr/Documents/code/phdtrack/Smart-and-Naive-SSH-Key-Extraction/smart_ssh_key_extractor/out
# DATASET_DIR_PATH: /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/

# %% [markdown]
# ## Functions

# %%
def get_run_length_encoded(data_block: np.ndarray):
    """
    Takes a data block of bytes.
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block.

    Example:
        data_block = [a,a,a,a,b,b,c,a,a]
        byte_array = [a,b,c,a]
        counts = [4,2,1,2]
    """

    idx = 1
    byte_array = []
    counts = []
    count = 1
    curr_char = data_block[0]
    while idx < len(data_block):
        if data_block[idx] == curr_char:
            idx += 1
            count += 1
            continue

        else:
            byte_array.append(curr_char)
            counts.append(count)

            count = 1
            curr_char = data_block[idx]

        idx += 1

    # Append the last byte and count
    byte_array.append(curr_char)
    counts.append(count)

    return bytearray(byte_array), counts

# %%
def generate_rle_representation(raw_data: bytearray):
    """
    Takes a data block of bytes (NOTE: byte == octet != bit).
    Determine for each byte the number of consecutive bytes.
    Returns the list of single bytes and their associated following number
    in the original data block, and the cumulative sum of the counts.
    """

    reshaped = np.reshape(raw_data, newshape=(int(len(raw_data) / 8), 8))

    # Here we take reshaped array and compute the numerical row and column wise gradient and count the number
    # of zeroes in each row. If there are more than 4 zeros which means there is a pattern repeating and
    # is not a key. This is a very conservative estimate for better recall
    num_row = int(len(raw_data) / 8)

    # x_grad = np.abs(np.diff(reshaped.astype(int), axis=1, append=np.zeros((num_row, 1)))).astype(bool)
    # y_grad = np.abs(np.diff(reshaped.astype(int), axis=0, append=np.zeros((1, 8)))).astype(bool)
    # The above numerical gradient computation is transformed into a single step below

    poss_key_locs = (np.count_nonzero(np.abs(np.diff(reshaped.astype(int), axis=1,
                                                     append=np.zeros((num_row, 1)))).astype(bool) &
                                      np.abs(np.diff(reshaped.astype(int), axis=0,
                                                     append=np.zeros((1, 8)))).astype(bool),
                                      axis=1) >= 4).astype(int)  # Changed from 4 to 3 to accommodate for 12 byte keys

    # This part addresses the issue of 12 byte keys. There could be two identical byte_array next to each other in the
    # last 4 bytes which would make it impossible for a key loc. We modify that if there is a possibility for a key
    idx = 1
    while idx < len(poss_key_locs):
        # Last 4 byte_array must be zeros and first four should have at least 3 unique byte_array
        if poss_key_locs[idx] == 0 and poss_key_locs[idx-1] == 1 and \
                all(reshaped[idx][4:]) == 0 and len(set(reshaped[idx][:4])) > 2:
            poss_key_locs[idx] = 1
        idx += 1

    # Roll the data to the left
    rolled = np.roll(poss_key_locs, -1)
    # The key cannot start at the last byte and then the block contain the whole key.
    # So the last value is set to False
    rolled[-1] = False
    poss_key_locs = (poss_key_locs & rolled).astype(int)

    # Roll right and OR it. The whole operation is similar to the opening morphological operation
    rolled = np.roll(poss_key_locs, 1)
    rolled[0] = False

    poss_key_locs = poss_key_locs | rolled

    byte_array, counts = get_run_length_encoded(poss_key_locs)

    cum_sum = [0]

    for idx in range(len(counts)):
        cum_sum.append(cum_sum[idx] + counts[idx])

    cum_sum = [x * 8 for x in cum_sum] # TODO: ???

    # The last offset is not required for the cumulative sum
    return byte_array, counts, cum_sum[:-1]

# %%
def get_slices(data, offsets, keys, max_key_size=128, deploy=False):
    """
    Takes a data block and a list of offsets.
    Cut the data block at the offsets and return a list of data blocks.
    Also return for each data block
    a label indicating if it contains a key or not. If deploy is True,
    the label is always 0.

    If we test the code (deploy=False), we additionnaly tests 
    if the data block contains a key.
    """

    data_blocks = []
    labels = []
    last_frame_added = False
    key_count = [0] * len(keys)
    for offset in offsets:
        if offset + max_key_size > len(data):
            curr_data = data[-max_key_size:]
            last_frame_added = True
        else:
            curr_data = data[offset:offset+max_key_size]
        data_blocks.append(curr_data)
        
        if deploy is True:
            labels.append(0)
            continue
            
        found = [l_idx for l_idx in range(len(keys)) if keys[l_idx] in curr_data]

        if len(found) > 0:
            labels.append(1)
            for key_idx in set(found):
                key_count[key_idx] += 1

        else:
            labels.append(0)

        if last_frame_added is True:
            break
    
    if deploy is False:
        assert len(data_blocks) == len(labels)
        assert sum(labels) > 0 and sum(labels) >= len(keys)
        assert min(key_count) != 0
    
    return data_blocks, labels

# %%
def build_encoded_dataset(heap_paths, key_paths, max_key_size=128, deploy=False):
    """
    Takes a list of heap paths and a list of key paths.
    For each heap path, it reads the heap file and the corresponding key file.
    It then generates a list of data blocks and a list of labels.
    The data blocks are generated by cutting the heap file at the offsets
    where a key is likely to be found. The labels indicate if the data block
    is sure to contains a key or not (when anotation is provided (deploy == False)).

    Returns a list of data blocks and a list of labels.
    """

    dataset = []
    labels = []
    for heap_path, key_path in zip(heap_paths, key_paths):

        # Check if the key path corresponds to the heap path, then read the required data
        curr_keys = ['EMPTY KEYS']
        if deploy is False:
            assert (key_path.replace(".json", "-heap.raw") == heap_path)
            curr_keys = read_key_files(key_path)
            # Remove repeated keys. This is an issue for some older versions of OpenSSH
            curr_keys = list(map(bytearray, set(tuple(x) for x in curr_keys)))

        with open(heap_path, "rb") as fp:
            data = bytearray(fp.read())
            
        byte_array, counts, cum_sum = generate_rle_representation(data)
        
        # a key can only starts with a byte of value 1, example: 00000001 10100111 101011001 ...
        viable_offsets = [cum_sum[idx] for idx in range(len(cum_sum)) if byte_array[idx] == 1]
        slices, curr_labels = get_slices(
            data=data, 
            offsets=viable_offsets, 
            max_key_size=max_key_size, 
            keys=curr_keys, 
            deploy=deploy
        )
        dataset.extend(slices)
        labels.extend(curr_labels)

    assert len(labels) == len(dataset)

    return dataset, labels

# %%
def generate_probable_slices(clf, heap_paths, key_paths, params: ProgramParameters):
    # Sort the heap paths and key paths, so it easier to group them by version and key length
    heap_paths.sort()
    key_paths.sort()
    
    # For each of the keys
    for idx in range(len(heap_paths)):
        start = time.time()

        key_path: str = ""
        if params.DEPLOY is False:
            key_path = key_paths[idx]
            
        dataset, curr_labels = build_encoded_dataset(
            heap_paths=[heap_paths[idx]],
            key_paths=[key_path], 
            deploy=params.DEPLOY
        )

        x_test = np.array(dataset).astype(int)
        curr_pred = clf.predict(x_test) # Make predictions

        # path manipulation to tranform input file paths to output file paths
        # example: transform "$INPUT/lastdir/heap.raw" to "$OUTPUT/lastdir/heap.txt
        file_name = os.path.basename(heap_paths[idx])
        file_name = file_name.replace(".raw", ".txt")
        sub_dir = os.path.dirname(heap_paths[idx]).split("/")[-1]
        dir_path = os.path.join(params.OUTPUT_DIR_PATH, sub_dir)
        output_path = os.path.join(dir_path, file_name)

        if os.path.exists(dir_path) is False:
            os.makedirs(dir_path)

        with open(output_path, 'w') as file:
            for inner_idx, pred in enumerate(curr_pred):
                # save if prediction not 0
                if pred != 0:
                    # format block to two digit hex
                    temp = ''.join(format(x, '02x') for x in dataset[inner_idx])
                    file.write(temp + "\n")

        end = time.time()
        log('Total time taken for file %s: %f' % (heap_paths[idx], (end - start)))

# %% [markdown]
# ## Execution

# %%
# Load the models
clf = load_models(load_high_recall_only=True)
print(type(clf))
# Out:
# 2023-01-12 11:17:54.595195:	Time taken for loading high recall classifier: 0.012833
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
# Search for all the files within the test directory
# start = time.time()
start = timer()
heap_paths, key_paths = get_dataset_file_paths(PARAMS.DATASET_DIR_PATH, deploy=PARAMS.DEPLOY)
end = timer()
# end = time.time()
log('Time taken for finding all files: %f' % (end - start))

# print first 5 values in heap_paths
print(
    "heap_paths (nbe: %i):" % len(heap_paths), 
    heap_paths[:5]
)
print(
    "key_paths: (nbe: %i):" % len(key_paths), 
    key_paths[:5]
)
if len(key_paths) == 0 and PARAMS.DEPLOY is False:
    print("No key paths found while deploy is False. Please check the dataset directory path.")
elif len(key_paths) == 0 and PARAMS.DEPLOY is True:
    print("No key paths found while deploy is True. This is expected.")
# Out:
# 2023-01-12 11:17:54.614193:	Time taken for finding all files: 0.002332
# heap_paths (nbe: 300): ['/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9966-1650981891-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9978-1650981891-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9996-1650981891-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10023-1650981891-heap.raw', '/home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10113-1650981891-heap.raw']
# key_paths: (nbe: 0): []
# No key paths found while deploy is True. This is expected.

# %%
generate_probable_slices(clf=clf, heap_paths=heap_paths, key_paths=key_paths, params=PARAMS)
# Out:
# 2023-01-12 11:17:54.640418:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10237-1650982250-heap.raw: 0.009732
# 2023-01-12 11:17:54.648348:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10240-1650982250-heap.raw: 0.007884
# 2023-01-12 11:17:54.656568:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10243-1650982250-heap.raw: 0.008194
# 2023-01-12 11:17:54.664074:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10246-1650982250-heap.raw: 0.007482
# 2023-01-12 11:17:54.671934:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10249-1650982250-heap.raw: 0.007832
# 2023-01-12 11:17:54.679897:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10252-1650982250-heap.raw: 0.007937
# 2023-01-12 11:17:54.688079:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10255-1650982250-heap.raw: 0.008144
# 2023-01-12 11:17:54.695861:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10258-1650982250-heap.raw: 0.007758
# 2023-01-12 11:17:54.726714:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10261-1650982250-heap.raw: 0.030826
# 2023-01-12 11:17:54.734139:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10264-1650982250-heap.raw: 0.007405
# 2023-01-12 11:17:54.742188:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10267-1650982250-heap.raw: 0.008021
# 2023-01-12 11:17:54.750210:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10270-1650982250-heap.raw: 0.007996
# 2023-01-12 11:17:54.758510:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10273-1650982250-heap.raw: 0.008270
# 2023-01-12 11:17:54.765923:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10276-1650982250-heap.raw: 0.007366
# 2023-01-12 11:17:54.773424:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10279-1650982250-heap.raw: 0.007476
# 2023-01-12 11:17:54.780792:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10282-1650982250-heap.raw: 0.007321
# 2023-01-12 11:17:54.788107:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10285-1650982250-heap.raw: 0.007295
# 2023-01-12 11:17:54.795578:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10288-1650982250-heap.raw: 0.007452
# 2023-01-12 11:17:54.803138:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10291-1650982250-heap.raw: 0.007542
# 2023-01-12 11:17:54.810877:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10294-1650982250-heap.raw: 0.007670
# 2023-01-12 11:17:54.818884:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10297-1650982250-heap.raw: 0.007985
# 2023-01-12 11:17:54.826998:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10300-1650982250-heap.raw: 0.008076
# 2023-01-12 11:17:54.834740:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10303-1650982250-heap.raw: 0.007720
# 2023-01-12 11:17:54.843401:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10306-1650982250-heap.raw: 0.008638
# 2023-01-12 11:17:54.850935:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10309-1650982250-heap.raw: 0.007502
# 2023-01-12 11:17:54.858655:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10312-1650982250-heap.raw: 0.007696
# 2023-01-12 11:17:54.865990:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10315-1650982250-heap.raw: 0.007314
# 2023-01-12 11:17:54.873538:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10318-1650982250-heap.raw: 0.007525
# 2023-01-12 11:17:54.880899:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10321-1650982250-heap.raw: 0.007341
# 2023-01-12 11:17:54.888390:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10324-1650982250-heap.raw: 0.007470
# 2023-01-12 11:17:54.896052:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10327-1650982250-heap.raw: 0.007626
# 2023-01-12 11:17:54.903527:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10330-1650982250-heap.raw: 0.007458
# 2023-01-12 11:17:54.911312:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10333-1650982250-heap.raw: 0.007764
# 2023-01-12 11:17:54.918696:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10336-1650982250-heap.raw: 0.007365
# 2023-01-12 11:17:54.926515:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10339-1650982250-heap.raw: 0.007799
# 2023-01-12 11:17:54.934038:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10342-1650982250-heap.raw: 0.007503
# 2023-01-12 11:17:54.941975:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10345-1650982250-heap.raw: 0.007912
# 2023-01-12 11:17:54.949560:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10348-1650982250-heap.raw: 0.007563
# 2023-01-12 11:17:54.957551:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10351-1650982250-heap.raw: 0.007967
# 2023-01-12 11:17:54.965264:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10354-1650982250-heap.raw: 0.007692
# 2023-01-12 11:17:54.973024:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10357-1650982250-heap.raw: 0.007736
# 2023-01-12 11:17:54.980699:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10360-1650982250-heap.raw: 0.007653
# 2023-01-12 11:17:54.988309:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10363-1650982250-heap.raw: 0.007588
# 2023-01-12 11:17:54.995786:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10366-1650982250-heap.raw: 0.007445
# 2023-01-12 11:17:55.003285:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10370-1650982250-heap.raw: 0.007454
# 2023-01-12 11:17:55.011329:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10373-1650982250-heap.raw: 0.008024
# 2023-01-12 11:17:55.019001:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10376-1650982250-heap.raw: 0.007635
# 2023-01-12 11:17:55.027024:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10379-1650982250-heap.raw: 0.008002
# 2023-01-12 11:17:55.034861:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10382-1650982250-heap.raw: 0.007800
# 2023-01-12 11:17:55.042566:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10385-1650982250-heap.raw: 0.007684
# 2023-01-12 11:17:55.050461:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10388-1650982250-heap.raw: 0.007874
# 2023-01-12 11:17:55.058482:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10391-1650982250-heap.raw: 0.007953
# 2023-01-12 11:17:55.066211:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10394-1650982250-heap.raw: 0.007708
# 2023-01-12 11:17:55.074032:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10397-1650982250-heap.raw: 0.007797
# 2023-01-12 11:17:55.081524:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10400-1650982250-heap.raw: 0.007472
# 2023-01-12 11:17:55.089379:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10403-1650982250-heap.raw: 0.007833
# 2023-01-12 11:17:55.097289:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10406-1650982250-heap.raw: 0.007868
# 2023-01-12 11:17:55.105097:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10409-1650982250-heap.raw: 0.007784
# 2023-01-12 11:17:55.112908:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10412-1650982250-heap.raw: 0.007788
# 2023-01-12 11:17:55.120356:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10415-1650982250-heap.raw: 0.007425
# 2023-01-12 11:17:55.128134:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10418-1650982250-heap.raw: 0.007756
# 2023-01-12 11:17:55.135741:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10421-1650982250-heap.raw: 0.007586
# 2023-01-12 11:17:55.144161:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10424-1650982250-heap.raw: 0.008394
# 2023-01-12 11:17:55.152072:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10427-1650982250-heap.raw: 0.007887
# 2023-01-12 11:17:55.160418:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10430-1650982250-heap.raw: 0.008318
# 2023-01-12 11:17:55.168485:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10433-1650982250-heap.raw: 0.008042
# 2023-01-12 11:17:55.176752:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10436-1650982250-heap.raw: 0.008242
# 2023-01-12 11:17:55.184530:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10439-1650982250-heap.raw: 0.007748
# 2023-01-12 11:17:55.192752:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10442-1650982250-heap.raw: 0.008195
# 2023-01-12 11:17:55.200364:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10445-1650982250-heap.raw: 0.007585
# 2023-01-12 11:17:55.208347:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10448-1650982250-heap.raw: 0.007958
# 2023-01-12 11:17:55.216528:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10451-1650982250-heap.raw: 0.008156
# 2023-01-12 11:17:55.224857:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10454-1650982250-heap.raw: 0.008278
# 2023-01-12 11:17:55.233915:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10457-1650982250-heap.raw: 0.009034
# 2023-01-12 11:17:55.242228:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10460-1650982250-heap.raw: 0.008273
# 2023-01-12 11:17:55.250054:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10463-1650982250-heap.raw: 0.007805
# 2023-01-12 11:17:55.258407:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10466-1650982250-heap.raw: 0.008330
# 2023-01-12 11:17:55.266485:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10469-1650982250-heap.raw: 0.008037
# 2023-01-12 11:17:55.274653:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10472-1650982250-heap.raw: 0.008147
# 2023-01-12 11:17:55.282496:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10475-1650982250-heap.raw: 0.007820
# 2023-01-12 11:17:55.290573:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10478-1650982250-heap.raw: 0.008054
# 2023-01-12 11:17:55.298630:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10481-1650982250-heap.raw: 0.008036
# 2023-01-12 11:17:55.306937:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10484-1650982250-heap.raw: 0.008265
# 2023-01-12 11:17:55.314727:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10487-1650982250-heap.raw: 0.007768
# 2023-01-12 11:17:55.322898:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10490-1650982250-heap.raw: 0.008148
# 2023-01-12 11:17:55.330728:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10493-1650982250-heap.raw: 0.007785
# 2023-01-12 11:17:55.338545:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10496-1650982250-heap.raw: 0.007795
# 2023-01-12 11:17:55.346110:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10499-1650982250-heap.raw: 0.007535
# 2023-01-12 11:17:55.353430:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10502-1650982250-heap.raw: 0.007301
# 2023-01-12 11:17:55.360962:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10505-1650982250-heap.raw: 0.007511
# 2023-01-12 11:17:55.368315:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10508-1650982250-heap.raw: 0.007309
# 2023-01-12 11:17:55.375962:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10511-1650982250-heap.raw: 0.007627
# 2023-01-12 11:17:55.383222:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10514-1650982250-heap.raw: 0.007240
# 2023-01-12 11:17:55.390704:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10517-1650982250-heap.raw: 0.007461
# 2023-01-12 11:17:55.398015:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10520-1650982250-heap.raw: 0.007292
# 2023-01-12 11:17:55.405389:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10523-1650982250-heap.raw: 0.007353
# 2023-01-12 11:17:55.412659:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10526-1650982250-heap.raw: 0.007251
# 2023-01-12 11:17:55.420300:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10529-1650982250-heap.raw: 0.007622
# 2023-01-12 11:17:55.427957:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10532-1650982250-heap.raw: 0.007594
# 2023-01-12 11:17:55.435644:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/16/10535-1650982250-heap.raw: 0.007674
# 2023-01-12 11:17:55.443388:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10538-1650982549-heap.raw: 0.007708
# 2023-01-12 11:17:55.450972:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10541-1650982549-heap.raw: 0.007565
# 2023-01-12 11:17:55.458649:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10544-1650982549-heap.raw: 0.007654
# 2023-01-12 11:17:55.466154:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10547-1650982549-heap.raw: 0.007485
# 2023-01-12 11:17:55.473996:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10550-1650982549-heap.raw: 0.007805
# 2023-01-12 11:17:55.481559:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10553-1650982549-heap.raw: 0.007542
# 2023-01-12 11:17:55.489113:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10556-1650982549-heap.raw: 0.007532
# 2023-01-12 11:17:55.496453:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10559-1650982549-heap.raw: 0.007324
# 2023-01-12 11:17:55.504246:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10562-1650982549-heap.raw: 0.007771
# 2023-01-12 11:17:55.511878:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10565-1650982549-heap.raw: 0.007596
# 2023-01-12 11:17:55.519423:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10568-1650982549-heap.raw: 0.007527
# 2023-01-12 11:17:55.526833:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10571-1650982549-heap.raw: 0.007390
# 2023-01-12 11:17:55.534094:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10574-1650982549-heap.raw: 0.007218
# 2023-01-12 11:17:55.541729:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10577-1650982549-heap.raw: 0.007613
# 2023-01-12 11:17:55.549199:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10580-1650982549-heap.raw: 0.007427
# 2023-01-12 11:17:55.556701:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10583-1650982549-heap.raw: 0.007481
# 2023-01-12 11:17:55.563998:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10586-1650982549-heap.raw: 0.007281
# 2023-01-12 11:17:55.571442:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10589-1650982549-heap.raw: 0.007421
# 2023-01-12 11:17:55.578717:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10592-1650982549-heap.raw: 0.007257
# 2023-01-12 11:17:55.585975:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10595-1650982549-heap.raw: 0.007240
# 2023-01-12 11:17:55.593506:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10598-1650982549-heap.raw: 0.007509
# 2023-01-12 11:17:55.600755:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10601-1650982549-heap.raw: 0.007234
# 2023-01-12 11:17:55.608461:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10607-1650982549-heap.raw: 0.007677
# 2023-01-12 11:17:55.615789:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10610-1650982549-heap.raw: 0.007312
# 2023-01-12 11:17:55.623931:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10613-1650982549-heap.raw: 0.008120
# 2023-01-12 11:17:55.631721:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10616-1650982549-heap.raw: 0.007756
# 2023-01-12 11:17:55.640192:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10619-1650982549-heap.raw: 0.008449
# 2023-01-12 11:17:55.648611:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10622-1650982549-heap.raw: 0.008380
# 2023-01-12 11:17:55.656952:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10625-1650982549-heap.raw: 0.008318
# 2023-01-12 11:17:55.664655:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10628-1650982549-heap.raw: 0.007682
# 2023-01-12 11:17:55.673402:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10631-1650982549-heap.raw: 0.008723
# 2023-01-12 11:17:55.681170:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10634-1650982549-heap.raw: 0.007717
# 2023-01-12 11:17:55.689496:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10637-1650982549-heap.raw: 0.008304
# 2023-01-12 11:17:55.697455:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10640-1650982549-heap.raw: 0.007937
# 2023-01-12 11:17:55.705159:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10643-1650982549-heap.raw: 0.007682
# 2023-01-12 11:17:55.713075:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10646-1650982549-heap.raw: 0.007894
# 2023-01-12 11:17:55.720819:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10649-1650982549-heap.raw: 0.007705
# 2023-01-12 11:17:55.728714:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10652-1650982549-heap.raw: 0.007870
# 2023-01-12 11:17:55.736157:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10655-1650982549-heap.raw: 0.007420
# 2023-01-12 11:17:55.744697:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10658-1650982549-heap.raw: 0.008513
# 2023-01-12 11:17:55.752864:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10661-1650982549-heap.raw: 0.008145
# 2023-01-12 11:17:55.761131:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10664-1650982549-heap.raw: 0.008239
# 2023-01-12 11:17:55.768959:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10667-1650982549-heap.raw: 0.007803
# 2023-01-12 11:17:55.776992:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10670-1650982549-heap.raw: 0.008006
# 2023-01-12 11:17:55.784515:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10673-1650982549-heap.raw: 0.007499
# 2023-01-12 11:17:55.792383:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10676-1650982549-heap.raw: 0.007844
# 2023-01-12 11:17:55.799869:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10679-1650982549-heap.raw: 0.007463
# 2023-01-12 11:17:55.807794:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10682-1650982549-heap.raw: 0.007897
# 2023-01-12 11:17:55.815316:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10685-1650982549-heap.raw: 0.007500
# 2023-01-12 11:17:55.823098:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10688-1650982549-heap.raw: 0.007758
# 2023-01-12 11:17:55.831298:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10691-1650982549-heap.raw: 0.008178
# 2023-01-12 11:17:55.839397:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10694-1650982549-heap.raw: 0.008051
# 2023-01-12 11:17:55.848474:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10697-1650982549-heap.raw: 0.009025
# 2023-01-12 11:17:55.857719:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10700-1650982549-heap.raw: 0.009201
# 2023-01-12 11:17:55.866397:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10703-1650982549-heap.raw: 0.008651
# 2023-01-12 11:17:55.875676:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10706-1650982549-heap.raw: 0.009251
# 2023-01-12 11:17:55.883646:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10709-1650982549-heap.raw: 0.007936
# 2023-01-12 11:17:55.891647:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10712-1650982549-heap.raw: 0.007978
# 2023-01-12 11:17:55.899364:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10715-1650982549-heap.raw: 0.007695
# 2023-01-12 11:17:55.907136:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10718-1650982549-heap.raw: 0.007749
# 2023-01-12 11:17:55.914806:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10721-1650982549-heap.raw: 0.007649
# 2023-01-12 11:17:55.922328:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10724-1650982549-heap.raw: 0.007487
# 2023-01-12 11:17:55.929763:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10727-1650982549-heap.raw: 0.007412
# 2023-01-12 11:17:55.937067:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10730-1650982549-heap.raw: 0.007284
# 2023-01-12 11:17:55.944577:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10733-1650982549-heap.raw: 0.007488
# 2023-01-12 11:17:55.951866:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10736-1650982549-heap.raw: 0.007269
# 2023-01-12 11:17:55.959403:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10739-1650982549-heap.raw: 0.007516
# 2023-01-12 11:17:55.966691:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10742-1650982549-heap.raw: 0.007268
# 2023-01-12 11:17:55.974219:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10745-1650982549-heap.raw: 0.007507
# 2023-01-12 11:17:55.981585:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10748-1650982549-heap.raw: 0.007347
# 2023-01-12 11:17:55.989089:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10751-1650982549-heap.raw: 0.007485
# 2023-01-12 11:17:55.996364:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10754-1650982549-heap.raw: 0.007256
# 2023-01-12 11:17:56.003693:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10757-1650982549-heap.raw: 0.007309
# 2023-01-12 11:17:56.011353:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10760-1650982549-heap.raw: 0.007640
# 2023-01-12 11:17:56.018659:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10763-1650982549-heap.raw: 0.007288
# 2023-01-12 11:17:56.026036:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10766-1650982549-heap.raw: 0.007347
# 2023-01-12 11:17:56.033815:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10769-1650982549-heap.raw: 0.007758
# 2023-01-12 11:17:56.041546:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10772-1650982549-heap.raw: 0.007693
# 2023-01-12 11:17:56.048981:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10775-1650982549-heap.raw: 0.007416
# 2023-01-12 11:17:56.056782:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10778-1650982549-heap.raw: 0.007780
# 2023-01-12 11:17:56.064515:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10781-1650982549-heap.raw: 0.007669
# 2023-01-12 11:17:56.072001:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10784-1650982549-heap.raw: 0.007440
# 2023-01-12 11:17:56.079740:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10787-1650982549-heap.raw: 0.007719
# 2023-01-12 11:17:56.087373:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10790-1650982549-heap.raw: 0.007588
# 2023-01-12 11:17:56.095086:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10793-1650982549-heap.raw: 0.007693
# 2023-01-12 11:17:56.102438:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10796-1650982549-heap.raw: 0.007333
# 2023-01-12 11:17:56.109961:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10799-1650982549-heap.raw: 0.007502
# 2023-01-12 11:17:56.117574:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10802-1650982549-heap.raw: 0.007595
# 2023-01-12 11:17:56.125323:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10805-1650982549-heap.raw: 0.007713
# 2023-01-12 11:17:56.132902:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10808-1650982549-heap.raw: 0.007560
# 2023-01-12 11:17:56.140396:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10811-1650982549-heap.raw: 0.007474
# 2023-01-12 11:17:56.147805:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10814-1650982549-heap.raw: 0.007394
# 2023-01-12 11:17:56.155555:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10817-1650982549-heap.raw: 0.007701
# 2023-01-12 11:17:56.163152:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10820-1650982549-heap.raw: 0.007580
# 2023-01-12 11:17:56.170632:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10823-1650982549-heap.raw: 0.007460
# 2023-01-12 11:17:56.178414:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10826-1650982549-heap.raw: 0.007764
# 2023-01-12 11:17:56.186061:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10829-1650982549-heap.raw: 0.007628
# 2023-01-12 11:17:56.193910:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10832-1650982549-heap.raw: 0.007829
# 2023-01-12 11:17:56.201448:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10835-1650982549-heap.raw: 0.007523
# 2023-01-12 11:17:56.209235:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/24/10838-1650982549-heap.raw: 0.007762
# 2023-01-12 11:17:56.216866:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10002-1650981891-heap.raw: 0.007612
# 2023-01-12 11:17:56.224887:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10005-1650981891-heap.raw: 0.007999
# 2023-01-12 11:17:56.232529:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10008-1650981891-heap.raw: 0.007623
# 2023-01-12 11:17:56.240565:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10011-1650981891-heap.raw: 0.008014
# 2023-01-12 11:17:56.248409:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10014-1650981891-heap.raw: 0.007811
# 2023-01-12 11:17:56.256369:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10017-1650981891-heap.raw: 0.007939
# 2023-01-12 11:17:56.264300:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10020-1650981891-heap.raw: 0.007914
# 2023-01-12 11:17:56.272129:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10023-1650981891-heap.raw: 0.007792
# 2023-01-12 11:17:56.279911:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10026-1650981891-heap.raw: 0.007759
# 2023-01-12 11:17:56.288155:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10029-1650981891-heap.raw: 0.008221
# 2023-01-12 11:17:56.296143:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10032-1650981891-heap.raw: 0.007951
# 2023-01-12 11:17:56.303801:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10035-1650981891-heap.raw: 0.007636
# 2023-01-12 11:17:56.311817:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10038-1650981891-heap.raw: 0.007990
# 2023-01-12 11:17:56.319558:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10041-1650981891-heap.raw: 0.007720
# 2023-01-12 11:17:56.327363:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10044-1650981891-heap.raw: 0.007769
# 2023-01-12 11:17:56.334957:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10047-1650981891-heap.raw: 0.007573
# 2023-01-12 11:17:56.342731:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10050-1650981891-heap.raw: 0.007750
# 2023-01-12 11:17:56.350166:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10053-1650981891-heap.raw: 0.007415
# 2023-01-12 11:17:56.358162:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10056-1650981891-heap.raw: 0.007973
# 2023-01-12 11:17:56.366060:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10059-1650981891-heap.raw: 0.007839
# 2023-01-12 11:17:56.374018:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10062-1650981891-heap.raw: 0.007933
# 2023-01-12 11:17:56.381903:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10065-1650981891-heap.raw: 0.007864
# 2023-01-12 11:17:56.389475:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10068-1650981891-heap.raw: 0.007549
# 2023-01-12 11:17:56.397307:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10071-1650981891-heap.raw: 0.007808
# 2023-01-12 11:17:56.405346:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10074-1650981891-heap.raw: 0.008016
# 2023-01-12 11:17:56.412949:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10077-1650981891-heap.raw: 0.007582
# 2023-01-12 11:17:56.420371:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10080-1650981891-heap.raw: 0.007401
# 2023-01-12 11:17:56.427990:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10083-1650981891-heap.raw: 0.007594
# 2023-01-12 11:17:56.435443:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10086-1650981891-heap.raw: 0.007430
# 2023-01-12 11:17:56.443394:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10089-1650981891-heap.raw: 0.007926
# 2023-01-12 11:17:56.450945:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10092-1650981891-heap.raw: 0.007499
# 2023-01-12 11:17:56.458557:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10095-1650981891-heap.raw: 0.007588
# 2023-01-12 11:17:56.466311:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10098-1650981891-heap.raw: 0.007738
# 2023-01-12 11:17:56.473930:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10101-1650981891-heap.raw: 0.007585
# 2023-01-12 11:17:56.481235:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10104-1650981891-heap.raw: 0.007285
# 2023-01-12 11:17:56.488744:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10107-1650981891-heap.raw: 0.007492
# 2023-01-12 11:17:56.496367:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10110-1650981891-heap.raw: 0.007594
# 2023-01-12 11:17:56.503812:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10113-1650981891-heap.raw: 0.007423
# 2023-01-12 11:17:56.511188:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10116-1650981891-heap.raw: 0.007355
# 2023-01-12 11:17:56.518417:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10119-1650981891-heap.raw: 0.007209
# 2023-01-12 11:17:56.526242:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10122-1650981891-heap.raw: 0.007805
# 2023-01-12 11:17:56.533733:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10125-1650981891-heap.raw: 0.007453
# 2023-01-12 11:17:56.541495:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10128-1650981891-heap.raw: 0.007740
# 2023-01-12 11:17:56.548743:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10131-1650981891-heap.raw: 0.007227
# 2023-01-12 11:17:56.556178:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10134-1650981891-heap.raw: 0.007413
# 2023-01-12 11:17:56.563748:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10137-1650981891-heap.raw: 0.007554
# 2023-01-12 11:17:56.571082:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10140-1650981891-heap.raw: 0.007304
# 2023-01-12 11:17:56.578432:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10143-1650981891-heap.raw: 0.007331
# 2023-01-12 11:17:56.585678:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10146-1650981891-heap.raw: 0.007228
# 2023-01-12 11:17:56.593209:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10149-1650981891-heap.raw: 0.007509
# 2023-01-12 11:17:56.600692:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10152-1650981891-heap.raw: 0.007468
# 2023-01-12 11:17:56.608451:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10155-1650981891-heap.raw: 0.007735
# 2023-01-12 11:17:56.615983:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10158-1650981891-heap.raw: 0.007517
# 2023-01-12 11:17:56.623973:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10161-1650981891-heap.raw: 0.007965
# 2023-01-12 11:17:56.631708:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10164-1650981891-heap.raw: 0.007720
# 2023-01-12 11:17:56.639427:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10167-1650981891-heap.raw: 0.007695
# 2023-01-12 11:17:56.647422:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10170-1650981891-heap.raw: 0.007975
# 2023-01-12 11:17:56.655402:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10173-1650981891-heap.raw: 0.007929
# 2023-01-12 11:17:56.663705:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10176-1650981891-heap.raw: 0.008278
# 2023-01-12 11:17:56.672217:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10179-1650981891-heap.raw: 0.008486
# 2023-01-12 11:17:56.681089:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10182-1650981891-heap.raw: 0.008829
# 2023-01-12 11:17:56.689974:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10185-1650981891-heap.raw: 0.008862
# 2023-01-12 11:17:56.698637:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10188-1650981891-heap.raw: 0.008610
# 2023-01-12 11:17:56.706771:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10191-1650981891-heap.raw: 0.008095
# 2023-01-12 11:17:56.715107:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10194-1650981891-heap.raw: 0.008310
# 2023-01-12 11:17:56.723222:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10197-1650981891-heap.raw: 0.008089
# 2023-01-12 11:17:56.731751:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10200-1650981891-heap.raw: 0.008501
# 2023-01-12 11:17:56.740335:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10203-1650981891-heap.raw: 0.008535
# 2023-01-12 11:17:56.748443:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10206-1650981891-heap.raw: 0.008078
# 2023-01-12 11:17:56.757238:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10209-1650981891-heap.raw: 0.008762
# 2023-01-12 11:17:56.766121:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10212-1650981891-heap.raw: 0.008847
# 2023-01-12 11:17:56.774997:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10215-1650981891-heap.raw: 0.008818
# 2023-01-12 11:17:56.783682:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10218-1650981891-heap.raw: 0.008652
# 2023-01-12 11:17:56.792556:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10221-1650981891-heap.raw: 0.008843
# 2023-01-12 11:17:56.800974:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10224-1650981891-heap.raw: 0.008390
# 2023-01-12 11:17:56.809163:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10227-1650981891-heap.raw: 0.008162
# 2023-01-12 11:17:56.816966:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10230-1650981891-heap.raw: 0.007778
# 2023-01-12 11:17:56.825395:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/10233-1650981891-heap.raw: 0.008405
# 2023-01-12 11:17:56.833475:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9936-1650981891-heap.raw: 0.008054
# 2023-01-12 11:17:56.841801:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9939-1650981891-heap.raw: 0.008298
# 2023-01-12 11:17:56.850697:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9942-1650981891-heap.raw: 0.008868
# 2023-01-12 11:17:56.859517:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9945-1650981891-heap.raw: 0.008776
# 2023-01-12 11:17:56.868137:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9948-1650981891-heap.raw: 0.008591
# 2023-01-12 11:17:56.876703:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9951-1650981891-heap.raw: 0.008541
# 2023-01-12 11:17:56.885223:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9954-1650981891-heap.raw: 0.008478
# 2023-01-12 11:17:56.894240:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9957-1650981891-heap.raw: 0.008990
# 2023-01-12 11:17:56.902753:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9960-1650981891-heap.raw: 0.008469
# 2023-01-12 11:17:56.911439:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9963-1650981891-heap.raw: 0.008653
# 2023-01-12 11:17:56.919819:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9966-1650981891-heap.raw: 0.008352
# 2023-01-12 11:17:56.927747:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9969-1650981891-heap.raw: 0.007905
# 2023-01-12 11:17:56.935763:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9972-1650981891-heap.raw: 0.007986
# 2023-01-12 11:17:56.943842:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9975-1650981891-heap.raw: 0.008040
# 2023-01-12 11:17:56.951984:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9978-1650981891-heap.raw: 0.008113
# 2023-01-12 11:17:56.960312:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9981-1650981891-heap.raw: 0.008298
# 2023-01-12 11:17:56.968411:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9984-1650981891-heap.raw: 0.008072
# 2023-01-12 11:17:56.976396:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9987-1650981891-heap.raw: 0.007958
# 2023-01-12 11:17:56.984498:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9990-1650981891-heap.raw: 0.008075
# 2023-01-12 11:17:56.992545:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9993-1650981891-heap.raw: 0.008022
# 2023-01-12 11:17:57.000120:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9996-1650981891-heap.raw: 0.007551
# 2023-01-12 11:17:57.007923:	Total time taken for file /home/onyr/Documents/code/phdtrack/phdtrack_data/Performance_Test/Performance_Test/V_7_1_P1/32/9999-1650981891-heap.raw: 0.007781

# %%
key_paths
# Out:
# []
